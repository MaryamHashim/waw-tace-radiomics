# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamHashim/waw-tace-radiomics/blob/master/notebooks/RadiomicsSigNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Develop Your First Radiomics Signature on CT Images
#
# a step-by-step, seamless experience as you learn to develop a radiomics signature on CT images using the WAW-TACE dataset. Follow the steps carefully to avoid common issues.

# %% [markdown]
# ## Setting the computing environment
#
# 1.	Sign in to Google Colab https://colab.research.google.com/  in Google Chrome (optimized browser), create a new notebook, save it > now it will create a folder in your google drive called (Colab Notebooks)
# Check location: Drive/My Drive/Colab Notebooks
# 2. sign in  Google Chrome> Google drive > Create a dedicated folder in Google Drive (e.g., Colab Notebooks/RadSignature).
# 3. GitHub Repository: Prepare the WAW-TACE-Radiomics GitHub Repository https://github.com/MaryamHashim/waw-tace-radiomics
# 4. Dataset: WAW-TACE Dataset Downloaded from Zenodo to your laptop> uncompress it > drag n drop into RadSignature folder in google drive
# 5. Check the number of files in each folder as follows:
# ct_scans_1_4_wawtace_09_05_24 :  56 files
# ct_scans_2_4_wawtace_09_05_24: 57 files
# ct_scans_3_4_wawtace_09_05_24: 57 files
# ct_scans_4_4_wawtace_09_05_24: 63 files
# organ_masks_wawtace_09_05_2024: 233 files
# tumor_masks_wawtace_v1_08_05_2024: 233 files
# ________________________________________

# %% [markdown]
# 1. Set the Runtime> CPU
# 2. Clone the GitHub Repository

# %%
# !git clone https://github.com/MaryamHashim/waw-tace-radiomics.git
# Out:
# Cloning into 'waw-tace-radiomics'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 140 (delta 58), reused 102 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 2.45 MiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %% [markdown]
# Navigate to the Correct Directory

# %%
# %cd waw-tace-radiomics/notebooks
# Out:
# /content/waw-tace-radiomics/notebooks

# %% [markdown]
# Verify the Library's Presence

# %%
# !ls
# Out:
# 1_image_preprocessing_and_radiomic_feature_extraction.ipynb  Radiomics_Signature.ipynb
# 2_model_training.ipynb					     Radiomics_Signature_Model.ipynb
# display_lib.py						     test_patients

# %% [markdown]
# Import the Library

# %%
# !pip install SimpleITK
# Out:
# Collecting SimpleITK
#   Downloading SimpleITK-2.4.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Downloading SimpleITK-2.4.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.4.1

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %% [markdown]
# Run Your Code

# %%
# %%capture
# %matplotlib inline

import SimpleITK as sitk
import numpy as np
from display_lib import VolumeDisplay, resample

# %%
# Mount Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the image path to your Google Drive folder
image_path = "/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10"

# %%
# Define a patient identifier
patient_id = "10"

# %%
# Create a dictionary relating different images or the mask to the path
image_paths = {
    "pre": f"{image_path}/{patient_id}_0_scan.nii.gz",  # Correct path without extra patient_id
    "arterial": f"{image_path}/{patient_id}_1_scan.nii.gz",  # Correct path without extra patient_id
    "portal": f"{image_path}/{patient_id}_2_scan.nii.gz",  # Correct path without extra patient_id
    "mask": f"/content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/{patient_id}/{patient_id}_2_0_tumor_seg.nrrd"  # Correct mask path
}

# %%
image_paths["mask"] = "/content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/10/10_2_0_tumor_seg.nrrd"

# %%
# Print paths again to verify correctness
print(f"Pre-scan path: {image_paths['pre']}")
print(f"Arterial scan path: {image_paths['arterial']}")
print(f"Portal scan path: {image_paths['portal']}")
print(f"Mask path: {image_paths['mask']}")
# Out:
# Pre-scan path: /content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10/10_0_scan.nii.gz
# Arterial scan path: /content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10/10_1_scan.nii.gz
# Portal scan path: /content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10/10_2_scan.nii.gz
# Mask path: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/10/10_2_0_tumor_seg.nrrd

# %% [markdown]
# # How to Visualize Your Data Before Building a Radiomics Signature

# %%
import SimpleITK as sitk

# Load the images and mask
arterial_image = sitk.ReadImage("/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10/10_1_scan.nii.gz")
portal_image = sitk.ReadImage("/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_1_4_wawtace_09_05_24/10/10_2_scan.nii.gz")
tumor_mask = sitk.ReadImage("/content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/10/10_2_0_tumor_seg.nrrd")

print("Arterial Image Size:", arterial_image.GetSize())
print("Portal Image Size:", portal_image.GetSize())
print("Tumor Mask Size:", tumor_mask.GetSize())
# Out:
# Arterial Image Size: (512, 512, 163)
# Portal Image Size: (512, 512, 172)
# Tumor Mask Size: (512, 512, 172)

# %%
# Use the volume displayer to visualize the scans
vol_display = VolumeDisplay(
    paths=[image_paths["arterial"], image_paths["portal"]],
    mask_path=image_paths["mask"]
)

vol_display()
# Out:
# interactive(children=(IntSlider(value=0, description='Slice index', max=162), ToggleButton(value=False, descri…

# %% [markdown]
# Now we have visualized patient no 10, let's update the dataset_path to include all patients

# %% [markdown]
# Lets run a code to point to the correct path for the mask folder.

# %%
import os

# Define the correct path to the mask folder
mask_base_dir = '/content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024'

# Function to list all mask files
def list_mask_files(mask_base_dir):
    for root, dirs, files in os.walk(mask_base_dir):
        for file_name in files:
            if file_name.endswith(('.nii', '.nii.gz')):  # Adjust extensions as needed
                print(f'Mask file found: {os.path.join(root, file_name)}')

list_mask_files(mask_base_dir)

# %%
# Print the directory structure to check accessibility
def check_directory_structure(mask_base_dir):
    print(f"Checking directory: {mask_base_dir}")
    for root, dirs, files in os.walk(mask_base_dir):
        print(f"Root: {root}")
        print(f"Subdirectories: {dirs}")
        print(f"Files: {files}")
        # If you find files in the directory, list them
        if files:
            for file_name in files:
                print(f"Found file: {file_name}")

check_directory_structure(mask_base_dir)
# Out:
# Checking directory: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024
# Subdirectories: ['101', '10', '103', '102', '104', '108', '118', '112', '114', '111', '116', '115', '126', '121', '125', '119', '134', '13', '127', '135', '139', '14', '146', '144', '142', '149', '158', '150', '15', '16', '171', '167', '179', '165', '169', '168', '184', '19', '188', '18', '193', '2', '192', '197', '190', '198', '24', '23', '20', '21', '26', '29', '3', '28', '27', '25', '31', '310', '303', '304', '315', '324', '325', '326', '318', '319', '328', '330', '327', '33', '335', '333', '332', '334', '339', '338', '337', '342', '34', '336', '345', '347', '343', '344', '354', '35', '353', '351', '350', '349', '358', '356', '36', '360', '37', '366', '368', '363', '369', '367', '372', '373', '371', '370', '378', '379', '374', '375', '38', '380', '385', '383', '381', '382', '393', '390', '388', '39', '394', '396', '399', '405', '404', '41', '436', '42', '434', '43', '438', '440', '44', '437', '439', '442', '443', '447', '446', '45', '450', '453', '452', '451', '460', '458', '456', '455', '46', '457', '462', '463', '465', '466', '469', '483', '474', '477', '48', '47', '484', '485', '486', '487', '493', '492', '494', '490', '491', '496', '5', '498', '500', '50', '517', '518', '514', '515', '503', '512', '508', '502', '510', '501', '524', '522', '519', '521', '533', '53', '531', '525', '527', '537', '539', '543', '540', '54', '59', '58', '60', '61', '56', '57', '62', '65', '66', '63', '7', '67', '74', '69', '72', '73', '79', '8', '80', '77', '84', '87', '85', '86', '81', '83', '88', '91', '89', '90', '95', '93', '96', '92', '94', '98', '99']
# Files: []
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/101
# Subdirectories: []
# Files: ['101_1_0_tumor_seg.nrrd', '101_1_1_tumor_seg.nrrd']
# Found file: 101_1_0_tumor_seg.nrrd
# Found file: 101_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/10
# Subdirectories: []
# Files: ['10_2_0_tumor_seg.nrrd']
# Found file: 10_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/103
# Subdirectories: []
# Files: ['103_1_3_tumor_seg.nrrd', '103_1_0_tumor_seg.nrrd', '103_1_2_tumor_seg.nrrd', '103_1_4_tumor_seg.nrrd', '103_1_1_tumor_seg.nrrd']
# Found file: 103_1_3_tumor_seg.nrrd
# Found file: 103_1_0_tumor_seg.nrrd
# Found file: 103_1_2_tumor_seg.nrrd
# Found file: 103_1_4_tumor_seg.nrrd
# Found file: 103_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/102
# Subdirectories: []
# Files: ['102_1_2_tumor_seg.nrrd', '102_1_1_tumor_seg.nrrd', '102_1_0_tumor_seg.nrrd', '102_1_4_tumor_seg.nrrd', '102_1_5_tumor_seg.nrrd', '102_1_3_tumor_seg.nrrd']
# Found file: 102_1_2_tumor_seg.nrrd
# Found file: 102_1_1_tumor_seg.nrrd
# Found file: 102_1_0_tumor_seg.nrrd
# Found file: 102_1_4_tumor_seg.nrrd
# Found file: 102_1_5_tumor_seg.nrrd
# Found file: 102_1_3_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/104
# Subdirectories: []
# Files: ['104_1_2_tumor_seg.nrrd', '104_1_0_tumor_seg.nrrd', '104_1_1_tumor_seg.nrrd', '104_1_3_tumor_seg.nrrd']
# Found file: 104_1_2_tumor_seg.nrrd
# Found file: 104_1_0_tumor_seg.nrrd
# Found file: 104_1_1_tumor_seg.nrrd
# Found file: 104_1_3_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/108
# Subdirectories: []
# Files: ['108_2_0_tumor_seg.nrrd']
# Found file: 108_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/118
# Subdirectories: []
# Files: ['118_1_0_tumor_seg.nrrd', '118_1_1_tumor_seg.nrrd']
# Found file: 118_1_0_tumor_seg.nrrd
# Found file: 118_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/112
# Subdirectories: []
# Files: ['112_2_0_tumor_seg.nrrd']
# Found file: 112_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/114
# Subdirectories: []
# Files: ['114_2_0_tumor_seg.nrrd']
# Found file: 114_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/111
# Subdirectories: []
# Files: ['111_1_0_tumor_seg.nrrd']
# Found file: 111_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/116
# Subdirectories: []
# Files: ['116_1_3_tumor_seg.nrrd', '116_1_2_tumor_seg.nrrd', '116_1_4_tumor_seg.nrrd', '116_1_0_tumor_seg.nrrd', '116_1_1_tumor_seg.nrrd']
# Found file: 116_1_3_tumor_seg.nrrd
# Found file: 116_1_2_tumor_seg.nrrd
# Found file: 116_1_4_tumor_seg.nrrd
# Found file: 116_1_0_tumor_seg.nrrd
# Found file: 116_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/115
# Subdirectories: []
# Files: ['115_2_0_tumor_seg.nrrd']
# Found file: 115_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/126
# Subdirectories: []
# Files: ['126_3_0_tumor_seg.nrrd']
# Found file: 126_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/121
# Subdirectories: []
# Files: ['121_1_0_tumor_seg.nrrd']
# Found file: 121_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/125
# Subdirectories: []
# Files: ['125_1_0_tumor_seg.nrrd', '125_1_1_tumor_seg.nrrd']
# Found file: 125_1_0_tumor_seg.nrrd
# Found file: 125_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/119
# Subdirectories: []
# Files: ['119_1_0_tumor_seg.nrrd', '119_1_2_tumor_seg.nrrd', '119_1_1_tumor_seg.nrrd']
# Found file: 119_1_0_tumor_seg.nrrd
# Found file: 119_1_2_tumor_seg.nrrd
# Found file: 119_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/134
# Subdirectories: []
# Files: ['134_3_0_tumor_seg.nrrd', '134_3_1_tumor_seg.nrrd']
# Found file: 134_3_0_tumor_seg.nrrd
# Found file: 134_3_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/13
# Subdirectories: []
# Files: ['13_0_0_tumor_seg.nrrd']
# Found file: 13_0_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/127
# Subdirectories: []
# Files: ['127_1_1_tumor_seg.nrrd', '127_1_2_tumor_seg.nrrd', '127_1_0_tumor_seg.nrrd', '127_1_3_tumor_seg.nrrd']
# Found file: 127_1_1_tumor_seg.nrrd
# Found file: 127_1_2_tumor_seg.nrrd
# Found file: 127_1_0_tumor_seg.nrrd
# Found file: 127_1_3_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/135
# Subdirectories: []
# Files: ['135_1_0_tumor_seg.nrrd']
# Found file: 135_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/139
# Subdirectories: []
# Files: ['139_2_1_tumor_seg.nrrd', '139_2_0_tumor_seg.nrrd']
# Found file: 139_2_1_tumor_seg.nrrd
# Found file: 139_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/14
# Subdirectories: []
# Files: ['14_1_2_tumor_seg.nrrd', '14_1_0_tumor_seg.nrrd', '14_1_1_tumor_seg.nrrd']
# Found file: 14_1_2_tumor_seg.nrrd
# Found file: 14_1_0_tumor_seg.nrrd
# Found file: 14_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/146
# Subdirectories: []
# Files: ['146_2_0_tumor_seg.nrrd']
# Found file: 146_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/144
# Subdirectories: []
# Files: ['144_1_0_tumor_seg.nrrd', '144_1_1_tumor_seg.nrrd']
# Found file: 144_1_0_tumor_seg.nrrd
# Found file: 144_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/142
# Subdirectories: []
# Files: ['142_3_0_tumor_seg.nrrd']
# Found file: 142_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/149
# Subdirectories: []
# Files: ['149_1_0_tumor_seg.nrrd']
# Found file: 149_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/158
# Subdirectories: []
# Files: ['158_2_0_tumor_seg.nrrd']
# Found file: 158_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/150
# Subdirectories: []
# Files: ['150_2_0_tumor_seg.nrrd']
# Found file: 150_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/15
# Subdirectories: []
# Files: ['15_2_0_tumor_seg.nrrd']
# Found file: 15_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/16
# Subdirectories: []
# Files: ['16_1_0_tumor_seg.nrrd', '16_1_1_tumor_seg.nrrd']
# Found file: 16_1_0_tumor_seg.nrrd
# Found file: 16_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/171
# Subdirectories: []
# Files: ['171_2_1_tumor_seg.nrrd', '171_2_0_tumor_seg.nrrd']
# Found file: 171_2_1_tumor_seg.nrrd
# Found file: 171_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/167
# Subdirectories: []
# Files: ['167_1_2_tumor_seg.nrrd', '167_1_0_tumor_seg.nrrd', '167_1_1_tumor_seg.nrrd']
# Found file: 167_1_2_tumor_seg.nrrd
# Found file: 167_1_0_tumor_seg.nrrd
# Found file: 167_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/179
# Subdirectories: []
# Files: ['179_1_2_tumor_seg.nrrd', '179_1_0_tumor_seg.nrrd', '179_1_1_tumor_seg.nrrd']
# Found file: 179_1_2_tumor_seg.nrrd
# Found file: 179_1_0_tumor_seg.nrrd
# Found file: 179_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/165
# Subdirectories: []
# Files: ['165_2_0_tumor_seg.nrrd']
# Found file: 165_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/169
# Subdirectories: []
# Files: ['169_2_0_tumor_seg.nrrd']
# Found file: 169_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/168
# Subdirectories: []
# Files: ['168_2_0_tumor_seg.nrrd']
# Found file: 168_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/184
# Subdirectories: []
# Files: ['184_2_0_tumor_seg.nrrd']
# Found file: 184_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/19
# Subdirectories: []
# Files: ['19_3_1_tumor_seg.nrrd', '19_3_0_tumor_seg.nrrd']
# Found file: 19_3_1_tumor_seg.nrrd
# Found file: 19_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/188
# Subdirectories: []
# Files: ['188_2_0_tumor_seg.nrrd']
# Found file: 188_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/18
# Subdirectories: []
# Files: ['18_2_0_tumor_seg.nrrd']
# Found file: 18_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/193
# Subdirectories: []
# Files: ['193_1_0_tumor_seg.nrrd']
# Found file: 193_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/2
# Subdirectories: []
# Files: ['2_1_0_tumor_seg.nrrd', '2_1_1_tumor_seg.nrrd']
# Found file: 2_1_0_tumor_seg.nrrd
# Found file: 2_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/192
# Subdirectories: []
# Files: ['192_1_0_tumor_seg.nrrd']
# Found file: 192_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/197
# Subdirectories: []
# Files: ['197_2_1_tumor_seg.nrrd', '197_2_0_tumor_seg.nrrd']
# Found file: 197_2_1_tumor_seg.nrrd
# Found file: 197_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/190
# Subdirectories: []
# Files: ['190_1_0_tumor_seg.nrrd']
# Found file: 190_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/198
# Subdirectories: []
# Files: ['198_1_0_tumor_seg.nrrd']
# Found file: 198_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/24
# Subdirectories: []
# Files: ['24_2_0_tumor_seg.nrrd']
# Found file: 24_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/23
# Subdirectories: []
# Files: ['23_2_0_tumor_seg.nrrd']
# Found file: 23_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/20
# Subdirectories: []
# Files: ['20_1_0_tumor_seg.nrrd', '20_1_1_tumor_seg.nrrd']
# Found file: 20_1_0_tumor_seg.nrrd
# Found file: 20_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/21
# Subdirectories: []
# Files: ['21_1_0_tumor_seg.nrrd']
# Found file: 21_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/26
# Subdirectories: []
# Files: ['26_1_0_tumor_seg.nrrd']
# Found file: 26_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/29
# Subdirectories: []
# Files: ['29_1_1_tumor_seg.nrrd', '29_1_0_tumor_seg.nrrd', '29_1_2_tumor_seg.nrrd', '29_1_3_tumor_seg.nrrd']
# Found file: 29_1_1_tumor_seg.nrrd
# Found file: 29_1_0_tumor_seg.nrrd
# Found file: 29_1_2_tumor_seg.nrrd
# Found file: 29_1_3_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/3
# Subdirectories: []
# Files: ['3_2_0_tumor_seg.nrrd']
# Found file: 3_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/28
# Subdirectories: []
# Files: ['28_2_1_tumor_seg.nrrd', '28_2_0_tumor_seg.nrrd']
# Found file: 28_2_1_tumor_seg.nrrd
# Found file: 28_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/27
# Subdirectories: []
# Files: ['27_1_0_tumor_seg.nrrd', '27_1_1_tumor_seg.nrrd', '27_1_2_tumor_seg.nrrd']
# Found file: 27_1_0_tumor_seg.nrrd
# Found file: 27_1_1_tumor_seg.nrrd
# Found file: 27_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/25
# Subdirectories: []
# Files: ['25_2_0_tumor_seg.nrrd', '25_2_1_tumor_seg.nrrd', '25_2_2_tumor_seg.nrrd']
# Found file: 25_2_0_tumor_seg.nrrd
# Found file: 25_2_1_tumor_seg.nrrd
# Found file: 25_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/31
# Subdirectories: []
# Files: ['31_2_0_tumor_seg.nrrd']
# Found file: 31_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/310
# Subdirectories: []
# Files: ['310_1_0_tumor_seg.nrrd']
# Found file: 310_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/303
# Subdirectories: []
# Files: ['303_1_0_tumor_seg.nrrd']
# Found file: 303_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/304
# Subdirectories: []
# Files: ['304_1_0_tumor_seg.nrrd', '304_1_1_tumor_seg.nrrd']
# Found file: 304_1_0_tumor_seg.nrrd
# Found file: 304_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/315
# Subdirectories: []
# Files: ['315_3_1_tumor_seg.nrrd', '315_3_0_tumor_seg.nrrd']
# Found file: 315_3_1_tumor_seg.nrrd
# Found file: 315_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/324
# Subdirectories: []
# Files: ['324_1_0_tumor_seg.nrrd']
# Found file: 324_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/325
# Subdirectories: []
# Files: ['325_2_0_tumor_seg.nrrd']
# Found file: 325_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/326
# Subdirectories: []
# Files: ['326_3_1_tumor_seg.nrrd', '326_3_0_tumor_seg.nrrd']
# Found file: 326_3_1_tumor_seg.nrrd
# Found file: 326_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/318
# Subdirectories: []
# Files: ['318_2_0_tumor_seg.nrrd']
# Found file: 318_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/319
# Subdirectories: []
# Files: ['319_1_1_tumor_seg.nrrd', '319_1_2_tumor_seg.nrrd', '319_1_0_tumor_seg.nrrd']
# Found file: 319_1_1_tumor_seg.nrrd
# Found file: 319_1_2_tumor_seg.nrrd
# Found file: 319_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/328
# Subdirectories: []
# Files: ['328_3_0_tumor_seg.nrrd']
# Found file: 328_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/330
# Subdirectories: []
# Files: ['330_2_0_tumor_seg.nrrd']
# Found file: 330_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/327
# Subdirectories: []
# Files: ['327_2_1_tumor_seg.nrrd', '327_2_0_tumor_seg.nrrd']
# Found file: 327_2_1_tumor_seg.nrrd
# Found file: 327_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/33
# Subdirectories: []
# Files: ['33_1_1_tumor_seg.nrrd', '33_1_3_tumor_seg.nrrd', '33_1_4_tumor_seg.nrrd', '33_1_2_tumor_seg.nrrd', '33_1_0_tumor_seg.nrrd']
# Found file: 33_1_1_tumor_seg.nrrd
# Found file: 33_1_3_tumor_seg.nrrd
# Found file: 33_1_4_tumor_seg.nrrd
# Found file: 33_1_2_tumor_seg.nrrd
# Found file: 33_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/335
# Subdirectories: []
# Files: ['335_1_1_tumor_seg.nrrd', '335_1_0_tumor_seg.nrrd']
# Found file: 335_1_1_tumor_seg.nrrd
# Found file: 335_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/333
# Subdirectories: []
# Files: ['333_1_0_tumor_seg.nrrd']
# Found file: 333_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/332
# Subdirectories: []
# Files: ['332_2_0_tumor_seg.nrrd']
# Found file: 332_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/334
# Subdirectories: []
# Files: ['334_1_0_tumor_seg.nrrd', '334_1_1_tumor_seg.nrrd', '334_1_2_tumor_seg.nrrd']
# Found file: 334_1_0_tumor_seg.nrrd
# Found file: 334_1_1_tumor_seg.nrrd
# Found file: 334_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/339
# Subdirectories: []
# Files: ['339_2_0_tumor_seg.nrrd']
# Found file: 339_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/338
# Subdirectories: []
# Files: ['338_1_0_tumor_seg.nrrd']
# Found file: 338_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/337
# Subdirectories: []
# Files: ['337_2_0_tumor_seg.nrrd']
# Found file: 337_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/342
# Subdirectories: []
# Files: ['342_2_0_tumor_seg.nrrd']
# Found file: 342_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/34
# Subdirectories: []
# Files: ['34_3_0_tumor_seg.nrrd']
# Found file: 34_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/336
# Subdirectories: []
# Files: ['336_3_0_tumor_seg.nrrd']
# Found file: 336_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/345
# Subdirectories: []
# Files: ['345_1_0_tumor_seg.nrrd']
# Found file: 345_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/347
# Subdirectories: []
# Files: ['347_1_0_tumor_seg.nrrd', '347_1_1_tumor_seg.nrrd']
# Found file: 347_1_0_tumor_seg.nrrd
# Found file: 347_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/343
# Subdirectories: []
# Files: ['343_1_0_tumor_seg.nrrd']
# Found file: 343_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/344
# Subdirectories: []
# Files: ['344_1_0_tumor_seg.nrrd']
# Found file: 344_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/354
# Subdirectories: []
# Files: ['354_1_0_tumor_seg.nrrd']
# Found file: 354_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/35
# Subdirectories: []
# Files: ['35_1_0_tumor_seg.nrrd']
# Found file: 35_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/353
# Subdirectories: []
# Files: ['353_1_0_tumor_seg.nrrd']
# Found file: 353_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/351
# Subdirectories: []
# Files: ['351_1_0_tumor_seg.nrrd']
# Found file: 351_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/350
# Subdirectories: []
# Files: ['350_1_1_tumor_seg.nrrd', '350_1_2_tumor_seg.nrrd', '350_1_0_tumor_seg.nrrd']
# Found file: 350_1_1_tumor_seg.nrrd
# Found file: 350_1_2_tumor_seg.nrrd
# Found file: 350_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/349
# Subdirectories: []
# Files: ['349_1_0_tumor_seg.nrrd', '349_1_1_tumor_seg.nrrd']
# Found file: 349_1_0_tumor_seg.nrrd
# Found file: 349_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/358
# Subdirectories: []
# Files: ['358_1_0_tumor_seg.nrrd', '358_1_1_tumor_seg.nrrd']
# Found file: 358_1_0_tumor_seg.nrrd
# Found file: 358_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/356
# Subdirectories: []
# Files: ['356_2_0_tumor_seg.nrrd', '356_2_1_tumor_seg.nrrd']
# Found file: 356_2_0_tumor_seg.nrrd
# Found file: 356_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/36
# Subdirectories: []
# Files: ['36_1_1_tumor_seg.nrrd', '36_1_0_tumor_seg.nrrd']
# Found file: 36_1_1_tumor_seg.nrrd
# Found file: 36_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/360
# Subdirectories: []
# Files: ['360_1_0_tumor_seg.nrrd']
# Found file: 360_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/37
# Subdirectories: []
# Files: ['37_1_0_tumor_seg.nrrd']
# Found file: 37_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/366
# Subdirectories: []
# Files: ['366_2_0_tumor_seg.nrrd']
# Found file: 366_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/368
# Subdirectories: []
# Files: ['368_3_0_tumor_seg.nrrd']
# Found file: 368_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/363
# Subdirectories: []
# Files: ['363_2_0_tumor_seg.nrrd']
# Found file: 363_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/369
# Subdirectories: []
# Files: ['369_1_0_tumor_seg.nrrd']
# Found file: 369_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/367
# Subdirectories: []
# Files: ['367_1_0_tumor_seg.nrrd']
# Found file: 367_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/372
# Subdirectories: []
# Files: ['372_1_0_tumor_seg.nrrd']
# Found file: 372_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/373
# Subdirectories: []
# Files: ['373_1_0_tumor_seg.nrrd']
# Found file: 373_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/371
# Subdirectories: []
# Files: ['371_1_0_tumor_seg.nrrd']
# Found file: 371_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/370
# Subdirectories: []
# Files: ['370_1_1_tumor_seg.nrrd', '370_1_0_tumor_seg.nrrd', '370_1_2_tumor_seg.nrrd']
# Found file: 370_1_1_tumor_seg.nrrd
# Found file: 370_1_0_tumor_seg.nrrd
# Found file: 370_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/378
# Subdirectories: []
# Files: ['378_3_0_tumor_seg.nrrd']
# Found file: 378_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/379
# Subdirectories: []
# Files: ['379_2_0_tumor_seg.nrrd']
# Found file: 379_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/374
# Subdirectories: []
# Files: ['374_1_0_tumor_seg.nrrd', '374_1_1_tumor_seg.nrrd', '374_1_2_tumor_seg.nrrd']
# Found file: 374_1_0_tumor_seg.nrrd
# Found file: 374_1_1_tumor_seg.nrrd
# Found file: 374_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/375
# Subdirectories: []
# Files: ['375_3_0_tumor_seg.nrrd']
# Found file: 375_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/38
# Subdirectories: []
# Files: ['38_1_0_tumor_seg.nrrd', '38_1_1_tumor_seg.nrrd']
# Found file: 38_1_0_tumor_seg.nrrd
# Found file: 38_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/380
# Subdirectories: []
# Files: ['380_1_0_tumor_seg.nrrd']
# Found file: 380_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/385
# Subdirectories: []
# Files: ['385_2_0_tumor_seg.nrrd']
# Found file: 385_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/383
# Subdirectories: []
# Files: ['383_2_0_tumor_seg.nrrd']
# Found file: 383_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/381
# Subdirectories: []
# Files: ['381_1_1_tumor_seg.nrrd', '381_1_0_tumor_seg.nrrd']
# Found file: 381_1_1_tumor_seg.nrrd
# Found file: 381_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/382
# Subdirectories: []
# Files: ['382_1_2_tumor_seg.nrrd', '382_1_0_tumor_seg.nrrd', '382_1_1_tumor_seg.nrrd']
# Found file: 382_1_2_tumor_seg.nrrd
# Found file: 382_1_0_tumor_seg.nrrd
# Found file: 382_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/393
# Subdirectories: []
# Files: ['393_3_0_tumor_seg.nrrd']
# Found file: 393_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/390
# Subdirectories: []
# Files: ['390_1_0_tumor_seg.nrrd']
# Found file: 390_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/388
# Subdirectories: []
# Files: ['388_1_0_tumor_seg.nrrd']
# Found file: 388_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/39
# Subdirectories: []
# Files: ['39_1_1_tumor_seg.nrrd', '39_1_3_tumor_seg.nrrd', '39_1_2_tumor_seg.nrrd', '39_1_0_tumor_seg.nrrd']
# Found file: 39_1_1_tumor_seg.nrrd
# Found file: 39_1_3_tumor_seg.nrrd
# Found file: 39_1_2_tumor_seg.nrrd
# Found file: 39_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/394
# Subdirectories: []
# Files: ['394_2_1_tumor_seg.nrrd', '394_2_0_tumor_seg.nrrd']
# Found file: 394_2_1_tumor_seg.nrrd
# Found file: 394_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/396
# Subdirectories: []
# Files: ['396_1_0_tumor_seg.nrrd', '396_1_1_tumor_seg.nrrd']
# Found file: 396_1_0_tumor_seg.nrrd
# Found file: 396_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/399
# Subdirectories: []
# Files: ['399_1_0_tumor_seg.nrrd', '399_1_1_tumor_seg.nrrd']
# Found file: 399_1_0_tumor_seg.nrrd
# Found file: 399_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/405
# Subdirectories: []
# Files: ['405_3_0_tumor_seg.nrrd']
# Found file: 405_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/404
# Subdirectories: []
# Files: ['404_1_0_tumor_seg.nrrd']
# Found file: 404_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/41
# Subdirectories: []
# Files: ['41_3_0_tumor_seg.nrrd']
# Found file: 41_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/436
# Subdirectories: []
# Files: ['436_3_0_tumor_seg.nrrd']
# Found file: 436_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/42
# Subdirectories: []
# Files: ['42_2_0_tumor_seg.nrrd', '42_2_1_tumor_seg.nrrd']
# Found file: 42_2_0_tumor_seg.nrrd
# Found file: 42_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/434
# Subdirectories: []
# Files: ['434_2_1_tumor_seg.nrrd', '434_2_0_tumor_seg.nrrd', '434_2_2_tumor_seg.nrrd']
# Found file: 434_2_1_tumor_seg.nrrd
# Found file: 434_2_0_tumor_seg.nrrd
# Found file: 434_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/43
# Subdirectories: []
# Files: ['43_2_2_tumor_seg.nrrd', '43_2_0_tumor_seg.nrrd', '43_2_1_tumor_seg.nrrd']
# Found file: 43_2_2_tumor_seg.nrrd
# Found file: 43_2_0_tumor_seg.nrrd
# Found file: 43_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/438
# Subdirectories: []
# Files: ['438_1_2_tumor_seg.nrrd', '438_1_1_tumor_seg.nrrd', '438_1_0_tumor_seg.nrrd']
# Found file: 438_1_2_tumor_seg.nrrd
# Found file: 438_1_1_tumor_seg.nrrd
# Found file: 438_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/440
# Subdirectories: []
# Files: ['440_1_0_tumor_seg.nrrd', '440_1_1_tumor_seg.nrrd']
# Found file: 440_1_0_tumor_seg.nrrd
# Found file: 440_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/44
# Subdirectories: []
# Files: ['44_1_1_tumor_seg.nrrd', '44_1_0_tumor_seg.nrrd']
# Found file: 44_1_1_tumor_seg.nrrd
# Found file: 44_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/437
# Subdirectories: []
# Files: ['437_1_0_tumor_seg.nrrd', '437_1_1_tumor_seg.nrrd']
# Found file: 437_1_0_tumor_seg.nrrd
# Found file: 437_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/439
# Subdirectories: []
# Files: ['439_2_0_tumor_seg.nrrd']
# Found file: 439_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/442
# Subdirectories: []
# Files: ['442_1_0_tumor_seg.nrrd']
# Found file: 442_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/443
# Subdirectories: []
# Files: ['443_2_0_tumor_seg.nrrd']
# Found file: 443_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/447
# Subdirectories: []
# Files: ['447_1_0_tumor_seg.nrrd']
# Found file: 447_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/446
# Subdirectories: []
# Files: ['446_1_0_tumor_seg.nrrd', '446_1_1_tumor_seg.nrrd', '446_1_2_tumor_seg.nrrd']
# Found file: 446_1_0_tumor_seg.nrrd
# Found file: 446_1_1_tumor_seg.nrrd
# Found file: 446_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/45
# Subdirectories: []
# Files: ['45_1_0_tumor_seg.nrrd']
# Found file: 45_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/450
# Subdirectories: []
# Files: ['450_2_0_tumor_seg.nrrd']
# Found file: 450_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/453
# Subdirectories: []
# Files: ['453_2_1_tumor_seg.nrrd', '453_2_0_tumor_seg.nrrd']
# Found file: 453_2_1_tumor_seg.nrrd
# Found file: 453_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/452
# Subdirectories: []
# Files: ['452_1_0_tumor_seg.nrrd']
# Found file: 452_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/451
# Subdirectories: []
# Files: ['451_3_0_tumor_seg.nrrd']
# Found file: 451_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/460
# Subdirectories: []
# Files: ['460_3_0_tumor_seg.nrrd']
# Found file: 460_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/458
# Subdirectories: []
# Files: ['458_0_0_tumor_seg.nrrd']
# Found file: 458_0_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/456
# Subdirectories: []
# Files: ['456_3_0_tumor_seg.nrrd']
# Found file: 456_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/455
# Subdirectories: []
# Files: ['455_1_2_tumor_seg.nrrd', '455_1_0_tumor_seg.nrrd', '455_1_1_tumor_seg.nrrd', '455_1_3_tumor_seg.nrrd']
# Found file: 455_1_2_tumor_seg.nrrd
# Found file: 455_1_0_tumor_seg.nrrd
# Found file: 455_1_1_tumor_seg.nrrd
# Found file: 455_1_3_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/46
# Subdirectories: []
# Files: ['46_2_0_tumor_seg.nrrd']
# Found file: 46_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/457
# Subdirectories: []
# Files: ['457_1_0_tumor_seg.nrrd']
# Found file: 457_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/462
# Subdirectories: []
# Files: ['462_3_0_tumor_seg.nrrd']
# Found file: 462_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/463
# Subdirectories: []
# Files: ['463_3_0_tumor_seg.nrrd']
# Found file: 463_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/465
# Subdirectories: []
# Files: ['465_2_0_tumor_seg.nrrd']
# Found file: 465_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/466
# Subdirectories: []
# Files: ['466_1_0_tumor_seg.nrrd']
# Found file: 466_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/469
# Subdirectories: []
# Files: ['469_1_0_tumor_seg.nrrd', '469_1_1_tumor_seg.nrrd', '469_1_2_tumor_seg.nrrd']
# Found file: 469_1_0_tumor_seg.nrrd
# Found file: 469_1_1_tumor_seg.nrrd
# Found file: 469_1_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/483
# Subdirectories: []
# Files: ['483_1_0_tumor_seg.nrrd']
# Found file: 483_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/474
# Subdirectories: []
# Files: ['474_1_0_tumor_seg.nrrd']
# Found file: 474_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/477
# Subdirectories: []
# Files: ['477_1_0_tumor_seg.nrrd', '477_1_1_tumor_seg.nrrd']
# Found file: 477_1_0_tumor_seg.nrrd
# Found file: 477_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/48
# Subdirectories: []
# Files: ['48_2_0_tumor_seg.nrrd']
# Found file: 48_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/47
# Subdirectories: []
# Files: ['47_2_0_tumor_seg.nrrd']
# Found file: 47_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/484
# Subdirectories: []
# Files: ['484_1_0_tumor_seg.nrrd']
# Found file: 484_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/485
# Subdirectories: []
# Files: ['485_1_0_tumor_seg.nrrd', '485_1_1_tumor_seg.nrrd']
# Found file: 485_1_0_tumor_seg.nrrd
# Found file: 485_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/486
# Subdirectories: []
# Files: ['486_1_0_tumor_seg.nrrd', '486_1_1_tumor_seg.nrrd']
# Found file: 486_1_0_tumor_seg.nrrd
# Found file: 486_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/487
# Subdirectories: []
# Files: ['487_2_0_tumor_seg.nrrd', '487_2_1_tumor_seg.nrrd', '487_2_2_tumor_seg.nrrd']
# Found file: 487_2_0_tumor_seg.nrrd
# Found file: 487_2_1_tumor_seg.nrrd
# Found file: 487_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/493
# Subdirectories: []
# Files: ['493_3_0_tumor_seg.nrrd']
# Found file: 493_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/492
# Subdirectories: []
# Files: ['492_1_0_tumor_seg.nrrd']
# Found file: 492_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/494
# Subdirectories: []
# Files: ['494_2_1_tumor_seg.nrrd', '494_2_0_tumor_seg.nrrd', '494_2_2_tumor_seg.nrrd']
# Found file: 494_2_1_tumor_seg.nrrd
# Found file: 494_2_0_tumor_seg.nrrd
# Found file: 494_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/490
# Subdirectories: []
# Files: ['490_3_0_tumor_seg.nrrd']
# Found file: 490_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/491
# Subdirectories: []
# Files: ['491_2_3_tumor_seg.nrrd', '491_2_0_tumor_seg.nrrd', '491_2_2_tumor_seg.nrrd', '491_2_1_tumor_seg.nrrd']
# Found file: 491_2_3_tumor_seg.nrrd
# Found file: 491_2_0_tumor_seg.nrrd
# Found file: 491_2_2_tumor_seg.nrrd
# Found file: 491_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/496
# Subdirectories: []
# Files: ['496_1_0_tumor_seg.nrrd']
# Found file: 496_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/5
# Subdirectories: []
# Files: ['5_2_0_tumor_seg.nrrd']
# Found file: 5_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/498
# Subdirectories: []
# Files: ['498_2_0_tumor_seg.nrrd']
# Found file: 498_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/500
# Subdirectories: []
# Files: ['500_1_1_tumor_seg.nrrd', '500_1_0_tumor_seg.nrrd']
# Found file: 500_1_1_tumor_seg.nrrd
# Found file: 500_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/50
# Subdirectories: []
# Files: ['50_2_0_tumor_seg.nrrd']
# Found file: 50_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/517
# Subdirectories: []
# Files: ['517_1_0_tumor_seg.nrrd']
# Found file: 517_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/518
# Subdirectories: []
# Files: ['518_1_0_tumor_seg.nrrd', '518_1_2_tumor_seg.nrrd', '518_1_1_tumor_seg.nrrd']
# Found file: 518_1_0_tumor_seg.nrrd
# Found file: 518_1_2_tumor_seg.nrrd
# Found file: 518_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/514
# Subdirectories: []
# Files: ['514_2_0_tumor_seg.nrrd']
# Found file: 514_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/515
# Subdirectories: []
# Files: ['515_1_0_tumor_seg.nrrd']
# Found file: 515_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/503
# Subdirectories: []
# Files: ['503_1_0_tumor_seg.nrrd']
# Found file: 503_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/512
# Subdirectories: []
# Files: ['512_1_0_tumor_seg.nrrd']
# Found file: 512_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/508
# Subdirectories: []
# Files: ['508_1_0_tumor_seg.nrrd']
# Found file: 508_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/502
# Subdirectories: []
# Files: ['502_3_0_tumor_seg.nrrd']
# Found file: 502_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/510
# Subdirectories: []
# Files: ['510_1_1_tumor_seg.nrrd', '510_1_0_tumor_seg.nrrd']
# Found file: 510_1_1_tumor_seg.nrrd
# Found file: 510_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/501
# Subdirectories: []
# Files: ['501_0_0_tumor_seg.nrrd', '501_0_1_tumor_seg.nrrd']
# Found file: 501_0_0_tumor_seg.nrrd
# Found file: 501_0_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/524
# Subdirectories: []
# Files: ['524_1_0_tumor_seg.nrrd']
# Found file: 524_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/522
# Subdirectories: []
# Files: ['522_1_1_tumor_seg.nrrd', '522_1_0_tumor_seg.nrrd']
# Found file: 522_1_1_tumor_seg.nrrd
# Found file: 522_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/519
# Subdirectories: []
# Files: ['519_1_2_tumor_seg.nrrd', '519_1_0_tumor_seg.nrrd', '519_1_1_tumor_seg.nrrd']
# Found file: 519_1_2_tumor_seg.nrrd
# Found file: 519_1_0_tumor_seg.nrrd
# Found file: 519_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/521
# Subdirectories: []
# Files: ['521_2_0_tumor_seg.nrrd']
# Found file: 521_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/533
# Subdirectories: []
# Files: ['533_1_0_tumor_seg.nrrd']
# Found file: 533_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/53
# Subdirectories: []
# Files: ['53_1_1_tumor_seg.nrrd', '53_1_0_tumor_seg.nrrd']
# Found file: 53_1_1_tumor_seg.nrrd
# Found file: 53_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/531
# Subdirectories: []
# Files: ['531_1_0_tumor_seg.nrrd']
# Found file: 531_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/525
# Subdirectories: []
# Files: ['525_3_0_tumor_seg.nrrd']
# Found file: 525_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/527
# Subdirectories: []
# Files: ['527_1_0_tumor_seg.nrrd']
# Found file: 527_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/537
# Subdirectories: []
# Files: ['537_3_0_tumor_seg.nrrd']
# Found file: 537_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/539
# Subdirectories: []
# Files: ['539_1_0_tumor_seg.nrrd']
# Found file: 539_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/543
# Subdirectories: []
# Files: ['543_1_0_tumor_seg.nrrd']
# Found file: 543_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/540
# Subdirectories: []
# Files: ['540_2_0_tumor_seg.nrrd']
# Found file: 540_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/54
# Subdirectories: []
# Files: ['54_2_0_tumor_seg.nrrd', '54_2_1_tumor_seg.nrrd', '54_2_2_tumor_seg.nrrd']
# Found file: 54_2_0_tumor_seg.nrrd
# Found file: 54_2_1_tumor_seg.nrrd
# Found file: 54_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/59
# Subdirectories: []
# Files: ['59_2_0_tumor_seg.nrrd']
# Found file: 59_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/58
# Subdirectories: []
# Files: ['58_2_0_tumor_seg.nrrd']
# Found file: 58_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/60
# Subdirectories: []
# Files: ['60_2_0_tumor_seg.nrrd']
# Found file: 60_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/61
# Subdirectories: []
# Files: ['61_1_0_tumor_seg.nrrd']
# Found file: 61_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/56
# Subdirectories: []
# Files: ['56_2_0_tumor_seg.nrrd', '56_2_1_tumor_seg.nrrd']
# Found file: 56_2_0_tumor_seg.nrrd
# Found file: 56_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/57
# Subdirectories: []
# Files: ['57_3_0_tumor_seg.nrrd']
# Found file: 57_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/62
# Subdirectories: []
# Files: ['62_1_0_tumor_seg.nrrd']
# Found file: 62_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/65
# Subdirectories: []
# Files: ['65_2_1_tumor_seg.nrrd', '65_2_0_tumor_seg.nrrd', '65_2_2_tumor_seg.nrrd']
# Found file: 65_2_1_tumor_seg.nrrd
# Found file: 65_2_0_tumor_seg.nrrd
# Found file: 65_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/66
# Subdirectories: []
# Files: ['66_2_0_tumor_seg.nrrd']
# Found file: 66_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/63
# Subdirectories: []
# Files: ['63_1_0_tumor_seg.nrrd', '63_1_0.nrrd']
# Found file: 63_1_0_tumor_seg.nrrd
# Found file: 63_1_0.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/7
# Subdirectories: []
# Files: ['7_1_2_tumor_seg.nrrd', '7_1_0_tumor_seg.nrrd', '7_1_1_tumor_seg.nrrd']
# Found file: 7_1_2_tumor_seg.nrrd
# Found file: 7_1_0_tumor_seg.nrrd
# Found file: 7_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/67
# Subdirectories: []
# Files: ['67_2_0_tumor_seg.nrrd']
# Found file: 67_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/74
# Subdirectories: []
# Files: ['74_1_0_tumor_seg.nrrd']
# Found file: 74_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/69
# Subdirectories: []
# Files: ['69_1_0_tumor_seg.nrrd']
# Found file: 69_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/72
# Subdirectories: []
# Files: ['72_1_0_tumor_seg.nrrd']
# Found file: 72_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/73
# Subdirectories: []
# Files: ['73_1_0_tumor_seg.nrrd']
# Found file: 73_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/79
# Subdirectories: []
# Files: ['79_1_0_tumor_seg.nrrd']
# Found file: 79_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/8
# Subdirectories: []
# Files: ['8_1_0_tumor_seg.nrrd']
# Found file: 8_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/80
# Subdirectories: []
# Files: ['80_2_0_tumor_seg.nrrd', '80_2_1_tumor_seg.nrrd']
# Found file: 80_2_0_tumor_seg.nrrd
# Found file: 80_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/77
# Subdirectories: []
# Files: ['77_1_0_tumor_seg.nrrd']
# Found file: 77_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/84
# Subdirectories: []
# Files: ['84_1_0_tumor_seg.nrrd']
# Found file: 84_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/87
# Subdirectories: []
# Files: ['87_2_0_tumor_seg.nrrd', '87_2_1_tumor_seg.nrrd', '87_2_4_tumor_seg.nrrd', '87_2_3_tumor_seg.nrrd', '87_2_2_tumor_seg.nrrd']
# Found file: 87_2_0_tumor_seg.nrrd
# Found file: 87_2_1_tumor_seg.nrrd
# Found file: 87_2_4_tumor_seg.nrrd
# Found file: 87_2_3_tumor_seg.nrrd
# Found file: 87_2_2_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/85
# Subdirectories: []
# Files: ['85_1_0_tumor_seg.nrrd', '85_1_3_tumor_seg.nrrd', '85_1_2_tumor_seg.nrrd', '85_1_4_tumor_seg.nrrd', '85_1_1_tumor_seg.nrrd']
# Found file: 85_1_0_tumor_seg.nrrd
# Found file: 85_1_3_tumor_seg.nrrd
# Found file: 85_1_2_tumor_seg.nrrd
# Found file: 85_1_4_tumor_seg.nrrd
# Found file: 85_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/86
# Subdirectories: []
# Files: ['86_2_0_tumor_seg.nrrd']
# Found file: 86_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/81
# Subdirectories: []
# Files: ['81_1_0_tumor_seg.nrrd']
# Found file: 81_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/83
# Subdirectories: []
# Files: ['83_1_0_tumor_seg.nrrd', '83_1_2_tumor_seg.nrrd', '83_1_3_tumor_seg.nrrd', '83_1_4_tumor_seg.nrrd', '83_1_1_tumor_seg.nrrd']
# Found file: 83_1_0_tumor_seg.nrrd
# Found file: 83_1_2_tumor_seg.nrrd
# Found file: 83_1_3_tumor_seg.nrrd
# Found file: 83_1_4_tumor_seg.nrrd
# Found file: 83_1_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/88
# Subdirectories: []
# Files: ['88_2_0_tumor_seg.nrrd', '88_2_1_tumor_seg.nrrd']
# Found file: 88_2_0_tumor_seg.nrrd
# Found file: 88_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/91
# Subdirectories: []
# Files: ['91_1_1_tumor_seg.nrrd', '91_1_0_tumor_seg.nrrd']
# Found file: 91_1_1_tumor_seg.nrrd
# Found file: 91_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/89
# Subdirectories: []
# Files: ['89_2_0_tumor_seg.nrrd', '89_2_1_tumor_seg.nrrd']
# Found file: 89_2_0_tumor_seg.nrrd
# Found file: 89_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/90
# Subdirectories: []
# Files: ['90_2_0_tumor_seg.nrrd']
# Found file: 90_2_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/95
# Subdirectories: []
# Files: ['95_3_0_tumor_seg.nrrd']
# Found file: 95_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/93
# Subdirectories: []
# Files: ['93_2_0_tumor_seg.nrrd', '93_2_1_tumor_seg.nrrd']
# Found file: 93_2_0_tumor_seg.nrrd
# Found file: 93_2_1_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/96
# Subdirectories: []
# Files: ['96_1_0_tumor_seg.nrrd']
# Found file: 96_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/92
# Subdirectories: []
# Files: ['92_1_0_tumor_seg.nrrd']
# Found file: 92_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/94
# Subdirectories: []
# Files: ['94_1_1_tumor_seg.nrrd', '94_1_2_tumor_seg.nrrd', '94_1_0_tumor_seg.nrrd']
# Found file: 94_1_1_tumor_seg.nrrd
# Found file: 94_1_2_tumor_seg.nrrd
# Found file: 94_1_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/98
# Subdirectories: []
# Files: ['98_3_0_tumor_seg.nrrd']
# Found file: 98_3_0_tumor_seg.nrrd
# Root: /content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/99
# Subdirectories: []
# Files: ['99_3_0_tumor_seg.nrrd']
# Found file: 99_3_0_tumor_seg.nrrd

# %%
import os # library to interact with the operating system
from pathlib import Path # library to work with paths

image_path = "/content/drive/My Drive/Colab Notebooks/RadSignature"
# this defines a path object which we will use to recursively search for volumes
dataset_path = Path(image_path)

patient_phase_dictionary = {}

# this will collect all the volumes.
# we know that the relevant volumes have "_scan" in their name, so we will be filtering accordingly.
for volume_path in dataset_path.rglob("*nii.gz"):
    volume_path = str(volume_path)
    if "_scan" in volume_path:
        patient_id = volume_path.split(os.sep)[-2]
        if patient_id not in patient_phase_dictionary:
            patient_phase_dictionary[patient_id] = {}
        phase_id = volume_path.split(os.sep)[-1].split("_")[-2]
        patient_phase_dictionary[patient_id][phase_id] = volume_path

for volume_path in dataset_path.rglob("*nrrd"):
    volume_path = str(volume_path)
    patient_id = volume_path.split(os.sep)[-2]
    if patient_id in patient_phase_dictionary:
        if "masks" not in patient_phase_dictionary[patient_id]:
            patient_phase_dictionary[patient_id]["masks"] = []
        patient_phase_dictionary[patient_id]["masks"].append(volume_path)

print("Length of patient dictionary:", len(patient_phase_dictionary))
print("Number of patients with pre-contrast phase:", len([k for k in patient_phase_dictionary if "0" in patient_phase_dictionary[k]]))
print("Number of patients with arterial phase:", len([k for k in patient_phase_dictionary if "1" in patient_phase_dictionary[k]]))
print("Number of patients with portal phase:", len([k for k in patient_phase_dictionary if "2" in patient_phase_dictionary[k]]))
print("Number of patients with late phase:", len([k for k in patient_phase_dictionary if "3" in patient_phase_dictionary[k]]))
print("Number of patients with masks:", len([k for k in patient_phase_dictionary if "masks" in patient_phase_dictionary[k]]))

print("Number of patients with arterial and portal phases and masks:",
      len([
          k for k in patient_phase_dictionary
          if "1" in patient_phase_dictionary[k] and "2" in patient_phase_dictionary[k] and "masks" in patient_phase_dictionary[k]]))
# Out:
# Length of patient dictionary: 233
# Number of patients with pre-contrast phase: 200
# Number of patients with arterial phase: 230
# Number of patients with portal phase: 231
# Number of patients with late phase: 193
# Number of patients with masks: 233
# Number of patients with arterial and portal phases and masks: 229

# %% [markdown]
# ## After collecting all cases
#
# OK, now that we have been able to inspect our cases, we will focus on performing a small set of operations anticipating the radiomics feature extraction:
#
# 1. **Identify a common spacing** - different centers or protocols will use different spacings. Small changes to this may not have an impact on how radiologists interpret CT studies, but are likely to affect radiomic features. As such, we start by extracting the relevant spacing information
# 2. **Identify the minimum pixel value** - some radiomic features and image transformations are not very appropriate for negative values. For this reason, we will be shifting all values in the image to be positive
# 3. **Identify which cases are missing which series types** - after having a loose understanding of image characteristics, we will finally understand which phases are available for each patient

# %% [markdown]
# ### Extracting minimum intensity and spacing for all cases

# %%
from tqdm import tqdm # this is a progress bar - helpful to see how we are doing!

arterial_min_filter = sitk.MinimumMaximumImageFilter()
portal_min_filter = sitk.MinimumMaximumImageFilter()
property_dictionary = {}

for patient in tqdm(patient_phase_dictionary):
    # check if both arterial and portal are available
    if "1" in patient_phase_dictionary[patient] and "2" in patient_phase_dictionary[patient]:
        arterial_path = patient_phase_dictionary[patient]["1"]
        portal_path = patient_phase_dictionary[patient]["2"]
        arterial_image, portal_image = sitk.ReadImage(arterial_path), sitk.ReadImage(portal_path)
        arterial_min_filter.Execute(arterial_image)
        portal_min_filter.Execute(portal_image)
        property_dictionary[patient] = {
            "Arterial": {
                "path": arterial_path,
                "spacing": arterial_image.GetSpacing(),
                "minimum": arterial_min_filter.GetMinimum()
            },
            "Portal": {
                "path": portal_path,
                "spacing": portal_image.GetSpacing(),
                "minimum": portal_min_filter.GetMinimum()
            }
        }
# Out:
# 100%|██████████| 233/233 [27:34<00:00,  7.10s/it]

# %% [markdown]
# ### Picking a in-plane spacing
#
# Typically, there are variable in-plane and through-plane resolutions. So there is a necessity to standardise (or harmonize) this for radiomic feature extraction.
#
# Now that we have the spacing information for all images we have to make a decision: we know we need a common spacing. But different spacings come with compromises:
#
# - Picking the **minimum spacing** (highest resolution) - if this is applied to instances where the resolution is lower we will probably _create information_! By trying to increase the image resolution artificially, missing pixels and voxels are filled in with an educated guess. However, this can introduce biases!
# - Picking the **maximum spacing** (lowest resolution) - if this is applied to instances where the resolution is higher we will probably _lose information_!
# - Picking the **median spacing** - this is also intuitive, we try to achieve a compromise by upsampling some images and downsampling others. But we are still running a similar set of risks
#
# Ultimately this is a matter of **protocol design**: there is no _a priori_ correct answer but consistency matters. In other words, while the ideal solution is hard to determine, we are OK as long as we are consistent.
#
# To determine which method works best: empircally assess this for your use case! Maybe there is an ideal solution, maybe there isn't.
#
# #### Our (heuristic) solution
#
# Let's use the maximum spacing (lowest resolution). Since these tumours are relatively large, we should be losing little when we downsample them.

# %%
arterial_spacing_array = np.array([property_dictionary[k]["Arterial"]["spacing"] for k in property_dictionary])
portal_spacing_array = np.array([property_dictionary[k]["Arterial"]["spacing"] for k in property_dictionary])

for q in [0, 0.5, 1.0]:
    print(f"Spacing at quantile={q} (arterial):",
          np.quantile(arterial_spacing_array, q, axis=0))
    print(f"Spacing at quantile={q} (portal):",
          np.quantile(portal_spacing_array, q, axis=0))
# Out:
# Spacing at quantile=0 (arterial): [0.54296899 0.54296899 0.5       ]
# Spacing at quantile=0 (portal): [0.54296899 0.54296899 0.5       ]
# Spacing at quantile=0.5 (arterial): [0.77929699 0.77929699 1.25      ]
# Spacing at quantile=0.5 (portal): [0.77929699 0.77929699 1.25      ]
# Spacing at quantile=1.0 (arterial): [1.07500005 1.07500005 5.        ]
# Spacing at quantile=1.0 (portal): [1.07500005 1.07500005 5.        ]

# %% [markdown]
# ### Picking a through-plane spacing
#
# These images are not isometric (their spacing is not identical in all directions): only the xy (in-plane) spacing is identical, whereas the z (through-plane) spacing is different.
#
# Is this yet another decision we have to make? 😱
#
# Luckily, not really - while features can be extracted in 3 dimensions, we can force radiomic feature extraction to work with 2D features. This allows us to preserve the original through-plane spacing without introducing any biases from the resampling.

# %% [markdown]
# ## Radiomic feature extraction
#
# Now that we have a rough idea of the parameters necessary for radiomic feature extraction we can start extracting radiomic features!
#
# First let's define constants for the minimum values and for the spacing we want to apply to our radiomic feature extraction.

# %%
arterial_spacing = np.max(arterial_spacing_array, axis=0)[:2]
portal_spacing = np.max(portal_spacing_array, axis=0)[:2]
arterial_minimum_value = min([property_dictionary[k]["Arterial"]["minimum"] for k in property_dictionary])
portal_minimum_value = min([property_dictionary[k]["Portal"]["minimum"] for k in property_dictionary])

print("Arterial spacing:", arterial_spacing)
print("Portal spacing:", portal_spacing)
print("Arterial minimum value:", arterial_minimum_value)
print("Portal minimum value:", portal_minimum_value)
# Out:
# Arterial spacing: [1.07500005 1.07500005]
# Portal spacing: [1.07500005 1.07500005]
# Arterial minimum value: -10226.0
# Portal minimum value: -4531.0

# %% [markdown]
# Now, we need to construct the radiomic settings file named YAML. This typically follows a structure like the following:
#
# ```
# setting:
#   binWidth: 25 # bin width for texture features
#   label: 1 # label in the mask
#   interpolator: 'sitkBSpline' # interpolation
#   resampledPixelSpacing: [1.075, 1.075, 0.0] # specify here the pixel spacing
#   force2D: true # forces 2D feature extraction
#
# # Image transformations that are applied to the data
# imageType:
#   Original: {}
#
# # Featureclasses, from which features must be calculated. If a featureclass is not mentioned, no features are calculated
# # for that class. Otherwise, the specified features are calculated, or, if none are specified, all are calculated (excluding redundant/deprecated features).
# featureClass:
#   shape:
#   firstorder:
#   glcm:
#   glrlm:
#   glszm:
# ```
#
# We can automatically generate this with a Python dictionary, which we will then save in YAML format. We have to adjust both the `resampledPixelSpacing` (spacing) and the `voxelArrayShift` (sum to the pixel values).

# %%
import yaml
import os

# Define the initial parameters dictionary
params = {
    'imageType': {
        'Original': {},
    },
    'featureClass': {
        'firstorder': None,
        'shape': None,
        'glcm': None,
        'glrlm': None,
        'glszm': None,
        'gldm': None,
        'ngtdm': None,
    },
    'setting': {
        'binWidth': 25,
        'resampledPixelSpacing': [1.075, 1.075, 0.0],
        'voxelArrayShift': 2000,
        'force2D': True,
    }
}

# Replace these with the provided values
arterial_spacing = [1.07500005, 1.07500005]
portal_spacing = [1.07500005, 1.07500005]
arterial_minimum_value = -10226.0
portal_minimum_value = -4531.0

# Create copies of the template
params_arterial = params.copy()
params_portal = params.copy()

# Update arterial parameters
params_arterial["setting"]["resampledPixelSpacing"] = [*arterial_spacing, 0]  # Add 0 for z-dimension
params_arterial["setting"]["voxelArrayShift"] = int(arterial_minimum_value)

# Update portal parameters
params_portal["setting"]["resampledPixelSpacing"] = [*portal_spacing, 0]  # Add 0 for z-dimension
params_portal["setting"]["voxelArrayShift"] = int(portal_minimum_value)

# Create directory to store parameters
os.makedirs("params", exist_ok=True)

# Write arterial parameters to YAML file
with open("params/params-arterial.yaml", "w") as o:
    yaml.dump(params_arterial, o)

# Write portal parameters to YAML file
with open("params/params-portal.yaml", "w") as o:
    yaml.dump(params_portal, o)

# %%
import os
print(os.getcwd())
# Out:
# /content/waw-tace-radiomics/notebooks

# %%
# !ls -l params
# Out:
# total 8
# -rw-r--r-- 1 root root 267 Jan 28 21:16 params-arterial.yaml
# -rw-r--r-- 1 root root 267 Jan 28 21:16 params-portal.yaml

# %% [markdown]
# ### Finally extracting radiomic features!

# %%
# !pip install pyradiomics
# Out:
# Collecting pyradiomics
#   Downloading pyradiomics-3.1.0.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 18.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Discarding https://files.pythonhosted.org/packages/03/c1/20fc2c50ab1e3304da36d866042a1905a2b05a1431ece35448ab6b4578f2/pyradiomics-3.1.0.tar.gz (from https://pypi.org/simple/pyradiomics/): Requested pyradiomics from https://files.pythonhosted.org/packages/03/c1/20fc2c50ab1e3304da36d866042a1905a2b05a1431ece35448ab6b4578f2/pyradiomics-3.1.0.tar.gz has inconsistent version: expected '3.1.0', but metadata has '3.0.1a1'
#   Downloading pyradiomics-3.0.1.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 20.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from pyradiomics) (1.26.4)
# Requirement already satisfied: SimpleITK>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from pyradiomics) (2.4.1)
# Collecting PyWavelets>=0.4.0 (from pyradiomics)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting pykwalify>=1.6.0 (from pyradiomics)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from pyradiomics) (1.17.0)
# Collecting docopt>=0.6.2 (from pykwalify>=1.6.0->pyradiomics)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from pykwalify>=1.6.0->pyradiomics) (2.8.2)
# Collecting ruamel.yaml>=0.16.0 (from pykwalify>=1.6.0->pyradiomics)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16.0->pykwalify>=1.6.0->pyradiomics)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.3 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 9.2 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 36.9 MB/s eta 0:00:00
# Building wheels for collected packages: pyradiomics, docopt
#   Building wheel for pyradiomics (setup.py) ... done
#   Created wheel for pyradiomics: filename=pyradiomics-3.0.1-cp311-cp311-linux_x86_64.whl size=169816 sha256=ff496648854dc8d3a3710ba077349fd4709a35778ff0a568af07b31f5d7588d2
#   Stored in directory: /root/.cache/pip/wheels/57/fb/95/931a5364368a3d8eaf9eee0daaf186e64b75fea7c1c97949fb
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=883dbf052a33271adebdf16742637f81fd6100116eaf41878a18681241ae5378
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built pyradiomics docopt
# Installing collected packages: docopt, ruamel.yaml.clib, PyWavelets, ruamel.yaml, pykwalify, pyradiomics
# Successfully installed PyWavelets-1.8.0 docopt-0.6.2 pykwalify-1.8.0 pyradiomics-3.0.1 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12

# %%
from radiomics.featureextractor import RadiomicsFeatureExtractor
from radiomics import setVerbosity

setVerbosity(10)

# %%
patient_phase_dictionary["86"]
# Out:
# {'1': '/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_2_4_wawtace_09_05_24/86/86_1_scan.nii.gz',
#  '2': '/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_2_4_wawtace_09_05_24/86/86_2_scan.nii.gz',
#  '3': '/content/drive/My Drive/Colab Notebooks/RadSignature/ct_scans_2_4_wawtace_09_05_24/86/86_3_scan.nii.gz',
#  'masks': ['/content/drive/My Drive/Colab Notebooks/RadSignature/tumor_masks_wawtace_v1_08_05_2024/86/86_2_0_tumor_seg.nrrd']}

# %%
masks = [sitk.ReadImage(mask) for mask in patient_phase_dictionary["86"]["masks"]]
mask = sitk.Cast(sum([resample(mask, masks[0],is_mask=True) for mask in masks]) > 0, sitk.sitkUInt32)

arterial_volume = sitk.ReadImage(patient_phase_dictionary["86"]["1"])
arterial_mask = resample(mask, arterial_volume, is_mask=True)

arterial_rfe = RadiomicsFeatureExtractor("params/params-arterial.yaml")
arterial_features = arterial_rfe.execute(arterial_volume, arterial_mask)
# Out:
# Loading parameter file params/params-arterial.yaml
# INFO:radiomics.featureextractor:Loading parameter file params/params-arterial.yaml
# Parameters parsed, input is valid.
# DEBUG:radiomics.featureextractor:Parameters parsed, input is valid.
# Applying settings
# DEBUG:radiomics.featureextractor:Applying settings
# Enabled image types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled image types: {'Original': {}}
# Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# DEBUG:radiomics.featureextractor:Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# Settings: {'binWidth': 25, 'force2D': True, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'voxelArrayShift': -4531}
# DEBUG:radiomics.featureextractor:Settings: {'binWidth': 25, 'force2D': True, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'voxelArrayShift': -4531}
# Calculating features with label: 1
# INFO:radiomics.featureextractor:Calculating features with label: 1
# Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# DEBUG:radiomics.featureextractor:Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'voxelArrayShift': -4531}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'voxelArrayShift': -4531}
# Loading image and mask
# INFO:radiomics.featureextractor:Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# DEBUG:radiomics.imageoperations:Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking ROI validity
# Checking if label 1 is persent in the mask
# DEBUG:radiomics.imageoperations:Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((59.49999999999999, 162.5, 177.5), (229.49999999999997, 308.5, 342.5))
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((59.49999999999999, 162.5, 177.5), (229.49999999999997, 308.5, 342.5))
# ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.76300001 0.76300001 0.80004883] and size [512 512 351] to spacing [1.07500005 1.07500005 0.80004883] and size [132, 115, 177]
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.76300001 0.76300001 0.80004883] and size [512 512 351] to spacing [1.07500005 1.07500005 0.80004883] and size [132, 115, 177]
# Resampling image
# DEBUG:radiomics.imageoperations:Resampling image
# Resampling mask
# DEBUG:radiomics.imageoperations:Resampling mask
# Checking mask with label 1
# DEBUG:radiomics.imageoperations:Checking mask with label 1
# Calculating bounding box
# DEBUG:radiomics.imageoperations:Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# Cropping to size [120 103 165]
# DEBUG:radiomics.imageoperations:Cropping to size [120 103 165]
# Computing shape
# INFO:radiomics.featureextractor:Computing shape
# Initializing feature class
# DEBUG:radiomics.shape:Initializing feature class
# Padding the mask with 0s
# DEBUG:radiomics.shape:Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# Shape feature class initialized
# DEBUG:radiomics.shape:Shape feature class initialized
# Calculating features
# DEBUG:radiomics.shape:Calculating features
# Creating image type iterator
# DEBUG:radiomics.featureextractor:Creating image type iterator
# Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# Extracting features
# DEBUG:radiomics.featureextractor:Extracting features
# Yielding original image
# DEBUG:radiomics.imageoperations:Yielding original image
# Calculating features for original image
# INFO:radiomics.featureextractor:Calculating features for original image
# Cropping to size [120 103 165]
# DEBUG:radiomics.imageoperations:Cropping to size [120 103 165]
# Computing firstorder
# INFO:radiomics.featureextractor:Computing firstorder
# Initializing feature class
# DEBUG:radiomics.firstorder:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# First order feature class initialized
# DEBUG:radiomics.firstorder:First order feature class initialized
# Calculating features
# DEBUG:radiomics.firstorder:Calculating features
# Computing glcm
# INFO:radiomics.featureextractor:Computing glcm
# Initializing feature class
# DEBUG:radiomics.glcm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# Calculating GLCM matrix in C
# DEBUG:radiomics.glcm:Calculating GLCM matrix in C
# Process calculated matrix
# DEBUG:radiomics.glcm:Process calculated matrix
# Create symmetrical matrix
# DEBUG:radiomics.glcm:Create symmetrical matrix
# No empty angles
# DEBUG:radiomics.glcm:No empty angles
# Calculating GLCM coefficients
# DEBUG:radiomics.glcm:Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 60, 60, 4)
# DEBUG:radiomics.glcm:GLCM feature class initialized, calculated GLCM with shape (1, 60, 60, 4)
# Calculating features
# DEBUG:radiomics.glcm:Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING:radiomics.glcm:GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing gldm
# INFO:radiomics.featureextractor:Computing gldm
# Initializing feature class
# DEBUG:radiomics.gldm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# Calculating GLDM matrix in C
# DEBUG:radiomics.gldm:Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 60, 9)
# DEBUG:radiomics.gldm:Feature class initialized, calculated GLDM with shape (1, 60, 9)
# Calculating features
# DEBUG:radiomics.gldm:Calculating features
# Computing glrlm
# INFO:radiomics.featureextractor:Computing glrlm
# Initializing feature class
# DEBUG:radiomics.glrlm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# Calculating GLRLM matrix in C
# DEBUG:radiomics.glrlm:Calculating GLRLM matrix in C
# Process calculated matrix
# DEBUG:radiomics.glrlm:Process calculated matrix
# No empty angles
# DEBUG:radiomics.glrlm:No empty angles
# Calculating GLRLM coefficients
# DEBUG:radiomics.glrlm:Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 60, 21, 4)
# DEBUG:radiomics.glrlm:GLRLM feature class initialized, calculated GLRLM with shape (1, 60, 21, 4)
# Calculating features
# DEBUG:radiomics.glrlm:Calculating features
# Computing glszm
# INFO:radiomics.featureextractor:Computing glszm
# Initializing feature class
# DEBUG:radiomics.glszm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# Calculating GLSZM matrix in C
# DEBUG:radiomics.glszm:Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# DEBUG:radiomics.glszm:Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 60, 539)
# DEBUG:radiomics.glszm:GLSZM feature class initialized, calculated GLSZM with shape (1, 60, 539)
# Calculating features
# DEBUG:radiomics.glszm:Calculating features
# Computing ngtdm
# INFO:radiomics.featureextractor:Computing ngtdm
# Initializing feature class
# DEBUG:radiomics.ngtdm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# DEBUG:radiomics.imageoperations:Calculated 61 bins for bin width 25 with edges: [-1050 -1025 -1000  -975  -950  -925  -900  -875  -850  -825  -800  -775
#   -750  -725  -700  -675  -650  -625  -600  -575  -550  -525  -500  -475
#   -450  -425  -400  -375  -350  -325  -300  -275  -250  -225  -200  -175
#   -150  -125  -100   -75   -50   -25     0    25    50    75   100   125
#    150   175   200   225   250   275   300   325   350   375   400   425
#    450   475])
# Calculating features
# DEBUG:radiomics.ngtdm:Calculating features
# Features extracted
# DEBUG:radiomics.featureextractor:Features extracted

# %%
portal_volume = sitk.ReadImage(patient_phase_dictionary["86"]["2"])
portal_mask = resample(mask, portal_volume, is_mask=True)

portal_rfe = RadiomicsFeatureExtractor("params/params-portal.yaml")
portal_features = portal_rfe.execute(portal_volume, portal_mask)
# Out:
# Loading parameter file params/params-portal.yaml
# INFO:radiomics.featureextractor:Loading parameter file params/params-portal.yaml
# Parameters parsed, input is valid.
# DEBUG:radiomics.featureextractor:Parameters parsed, input is valid.
# Applying settings
# DEBUG:radiomics.featureextractor:Applying settings
# Enabled image types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled image types: {'Original': {}}
# Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# DEBUG:radiomics.featureextractor:Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# Settings: {'binWidth': 25, 'force2D': True, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'voxelArrayShift': -4531}
# DEBUG:radiomics.featureextractor:Settings: {'binWidth': 25, 'force2D': True, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'voxelArrayShift': -4531}
# Calculating features with label: 1
# INFO:radiomics.featureextractor:Calculating features with label: 1
# Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# DEBUG:radiomics.featureextractor:Enabled features: {'firstorder': None, 'glcm': None, 'gldm': None, 'glrlm': None, 'glszm': None, 'ngtdm': None, 'shape': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'voxelArrayShift': -4531}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.07500005, 1.07500005, 0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'voxelArrayShift': -4531}
# Loading image and mask
# INFO:radiomics.featureextractor:Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# DEBUG:radiomics.imageoperations:Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking ROI validity
# Checking if label 1 is persent in the mask
# DEBUG:radiomics.imageoperations:Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((67.5, 161.5, 359.5), (237.49999999999997, 307.5, 524.5))
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((67.5, 161.5, 359.5), (237.49999999999997, 307.5, 524.5))
# ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.76300001 0.76300001 0.80000001] and size [512 512 532] to spacing [1.07500005 1.07500005 0.80000001] and size [133, 116, 177]
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.76300001 0.76300001 0.80000001] and size [512 512 532] to spacing [1.07500005 1.07500005 0.80000001] and size [133, 116, 177]
# Resampling image
# DEBUG:radiomics.imageoperations:Resampling image
# Resampling mask
# DEBUG:radiomics.imageoperations:Resampling mask
# Checking mask with label 1
# DEBUG:radiomics.imageoperations:Checking mask with label 1
# Calculating bounding box
# DEBUG:radiomics.imageoperations:Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# Cropping to size [121 104 165]
# DEBUG:radiomics.imageoperations:Cropping to size [121 104 165]
# Computing shape
# INFO:radiomics.featureextractor:Computing shape
# Initializing feature class
# DEBUG:radiomics.shape:Initializing feature class
# Padding the mask with 0s
# DEBUG:radiomics.shape:Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# Shape feature class initialized
# DEBUG:radiomics.shape:Shape feature class initialized
# Calculating features
# DEBUG:radiomics.shape:Calculating features
# Creating image type iterator
# DEBUG:radiomics.featureextractor:Creating image type iterator
# Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# Extracting features
# DEBUG:radiomics.featureextractor:Extracting features
# Yielding original image
# DEBUG:radiomics.imageoperations:Yielding original image
# Calculating features for original image
# INFO:radiomics.featureextractor:Calculating features for original image
# Cropping to size [121 104 165]
# DEBUG:radiomics.imageoperations:Cropping to size [121 104 165]
# Computing firstorder
# INFO:radiomics.featureextractor:Computing firstorder
# Initializing feature class
# DEBUG:radiomics.firstorder:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# First order feature class initialized
# DEBUG:radiomics.firstorder:First order feature class initialized
# Calculating features
# DEBUG:radiomics.firstorder:Calculating features
# Computing glcm
# INFO:radiomics.featureextractor:Computing glcm
# Initializing feature class
# DEBUG:radiomics.glcm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# Calculating GLCM matrix in C
# DEBUG:radiomics.glcm:Calculating GLCM matrix in C
# Process calculated matrix
# DEBUG:radiomics.glcm:Process calculated matrix
# Create symmetrical matrix
# DEBUG:radiomics.glcm:Create symmetrical matrix
# No empty angles
# DEBUG:radiomics.glcm:No empty angles
# Calculating GLCM coefficients
# DEBUG:radiomics.glcm:Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 20, 20, 4)
# DEBUG:radiomics.glcm:GLCM feature class initialized, calculated GLCM with shape (1, 20, 20, 4)
# Calculating features
# DEBUG:radiomics.glcm:Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING:radiomics.glcm:GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing gldm
# INFO:radiomics.featureextractor:Computing gldm
# Initializing feature class
# DEBUG:radiomics.gldm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# Calculating GLDM matrix in C
# DEBUG:radiomics.gldm:Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 20, 9)
# DEBUG:radiomics.gldm:Feature class initialized, calculated GLDM with shape (1, 20, 9)
# Calculating features
# DEBUG:radiomics.gldm:Calculating features
# Computing glrlm
# INFO:radiomics.featureextractor:Computing glrlm
# Initializing feature class
# DEBUG:radiomics.glrlm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# Calculating GLRLM matrix in C
# DEBUG:radiomics.glrlm:Calculating GLRLM matrix in C
# Process calculated matrix
# DEBUG:radiomics.glrlm:Process calculated matrix
# No empty angles
# DEBUG:radiomics.glrlm:No empty angles
# Calculating GLRLM coefficients
# DEBUG:radiomics.glrlm:Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 20, 20, 4)
# DEBUG:radiomics.glrlm:GLRLM feature class initialized, calculated GLRLM with shape (1, 20, 20, 4)
# Calculating features
# DEBUG:radiomics.glrlm:Calculating features
# Computing glszm
# INFO:radiomics.featureextractor:Computing glszm
# Initializing feature class
# DEBUG:radiomics.glszm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# Calculating GLSZM matrix in C
# DEBUG:radiomics.glszm:Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# DEBUG:radiomics.glszm:Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 20, 613)
# DEBUG:radiomics.glszm:GLSZM feature class initialized, calculated GLSZM with shape (1, 20, 613)
# Calculating features
# DEBUG:radiomics.glszm:Calculating features
# Computing ngtdm
# INFO:radiomics.featureextractor:Computing ngtdm
# Initializing feature class
# DEBUG:radiomics.ngtdm:Initializing feature class
# Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# DEBUG:radiomics.imageoperations:Calculated 21 bins for bin width 25 with edges: [-300 -275 -250 -225 -200 -175 -150 -125 -100  -75  -50  -25    0   25
#    50   75  100  125  150  175  200  225])
# Calculating features
# DEBUG:radiomics.ngtdm:Calculating features
# Features extracted
# DEBUG:radiomics.featureextractor:Features extracted

# %%
from pprint import pprint

pprint(portal_features)
# Out:
# OrderedDict([('diagnostics_Versions_PyRadiomics', 'v3.0.1'),
#              ('diagnostics_Versions_Numpy', '1.26.4'),
#              ('diagnostics_Versions_SimpleITK', '2.4.1'),
#              ('diagnostics_Versions_PyWavelet', '1.8.0'),
#              ('diagnostics_Versions_Python', '3.11.11'),
#              ('diagnostics_Configuration_Settings',
#               {'additionalInfo': True,
#                'binWidth': 25,
#                'distances': [1],
#                'force2D': True,
#                'force2Ddimension': 0,
#                'interpolator': 'sitkBSpline',
#                'label': 1,
#                'minimumROIDimensions': 2,
#                'minimumROISize': None,
#                'normalize': False,
#                'normalizeScale': 1,
#                'padDistance': 5,
#                'preCrop': False,
#                'removeOutliers': None,
#                'resampledPixelSpacing': [1.07500005, 1.07500005, 0],
#                'resegmentRange': None,
#                'voxelArrayShift': -4531}),
#              ('diagnostics_Configuration_EnabledImageTypes', {'Original': {}}),
#              ('diagnostics_Image-original_Hash',
#               'b3867a1180ab95e9fda7e0f83e6fbf181c291556'),
#              ('diagnostics_Image-original_Dimensionality', '3D'),
#              ('diagnostics_Image-original_Spacing',
#               (0.7630000114440918, 0.7630000114440918, 0.800000011920929)),
#              ('diagnostics_Image-original_Size', (512, 512, 532)),
#              ('diagnostics_Image-original_Mean', -713.5266659958918),
#              ('diagnostics_Image-original_Minimum', -2048.0),
#              ('diagnostics_Image-original_Maximum', 1543.0),
#              ('diagnostics_Mask-original_Hash',
#               'a2e143e3e1220ba82abfd557f99d8b654ee60618'),
#              ('diagnostics_Mask-original_Spacing',
#               (0.7630000114440918, 0.7630000114440918, 0.800000011920929)),
#              ('diagnostics_Mask-original_Size', (512, 512, 532)),
#              ('diagnostics_Mask-original_BoundingBox',
#               (68, 162, 360, 170, 146, 165)),
#              ('diagnostics_Mask-original_VoxelNum', 1954270),
#              ('diagnostics_Mask-original_VolumeNum', 1),
#              ('diagnostics_Mask-original_CenterOfMassIndex',
#               (143.07850348211863, 236.59641758815312, 442.68022330588917)),
#              ('diagnostics_Mask-original_CenterOfMass',
#               (-85.76209996159933, -3.1391734533684996, 1579.3441350937458)),
#              ('diagnostics_Image-interpolated_Spacing',
#               (1.07500005, 1.07500005, 0.800000011920929)),
#              ('diagnostics_Image-interpolated_Size', (133, 116, 177)),
#              ('diagnostics_Image-interpolated_Mean', -84.1464378362622),
#              ('diagnostics_Image-interpolated_Minimum', -1056.0),
#              ('diagnostics_Image-interpolated_Maximum', 1242.0),
#              ('diagnostics_Mask-interpolated_Spacing',
#               (1.07500005, 1.07500005, 0.800000011920929)),
#              ('diagnostics_Mask-interpolated_Size', (133, 116, 177)),
#              ('diagnostics_Mask-interpolated_BoundingBox',
#               (6, 6, 6, 121, 104, 165)),
#              ('diagnostics_Mask-interpolated_VoxelNum', 985007),
#              ('diagnostics_Mask-interpolated_VolumeNum', 1),
#              ('diagnostics_Mask-interpolated_CenterOfMassIndex',
#               (59.410370687721, 58.77811223676583, 88.67899517465358)),
#              ('diagnostics_Mask-interpolated_CenterOfMass',
#               (-85.7588461767628, -3.133583188683417, 1579.3431525887427)),
#              ('diagnostics_Mask-interpolated_Mean', 70.5060248302804),
#              ('diagnostics_Mask-interpolated_Minimum', -279.0),
#              ('diagnostics_Mask-interpolated_Maximum', 195.0),
#              ('original_shape_Elongation', 0.8653231929845295),
#              ('original_shape_Flatness', 0.6889474227290985),
#              ('original_shape_LeastAxisLength', 89.01512932626763),
#              ('original_shape_MajorAxisLength', 129.20453199992497),
#              ('original_shape_Maximum2DDiameterColumn', array(143.57284277)),
#              ('original_shape_Maximum2DDiameterRow', array(137.79214956)),
#              ('original_shape_Maximum2DDiameterSlice', array(132.57849707)),
#              ('original_shape_Maximum3DDiameter', array(152.94150061)),
#              ('original_shape_MeshVolume', array(910514.26226673)),
#              ('original_shape_MinorAxisLength', 111.80367817824688),
#              ('original_shape_Sphericity', array(0.8424125)),
#              ('original_shape_SurfaceArea', array(53928.35296875)),
#              ('original_shape_SurfaceVolumeRatio', array(0.05922845)),
#              ('original_shape_VoxelVolume', 910639.0697801835),
#              ('original_firstorder_10Percentile', array(36.)),
#              ('original_firstorder_90Percentile', array(102.)),
#              ('original_firstorder_Energy', array(1.95983801e+13)),
#              ('original_firstorder_Entropy', array(2.14865392)),
#              ('original_firstorder_InterquartileRange', array(34.)),
#              ('original_firstorder_Kurtosis', array(4.25793974)),
#              ('original_firstorder_Maximum', array(195.)),
#              ('original_firstorder_MeanAbsoluteDeviation', array(20.59409922)),
#              ('original_firstorder_Mean', array(70.50602483)),
#              ('original_firstorder_Median', array(72.)),
#              ('original_firstorder_Minimum', array(-279.)),
#              ('original_firstorder_Range', array(474.)),
#              ('original_firstorder_RobustMeanAbsoluteDeviation',
#               array(14.29847024)),
#              ('original_firstorder_RootMeanSquared', array(4460.57072001)),
#              ('original_firstorder_Skewness', array(-0.41632103)),
#              ('original_firstorder_TotalEnergy', array(1.81187043e+13)),
#              ('original_firstorder_Uniformity', array(0.26546601)),
#              ('original_firstorder_Variance', array(684.64572333)),
#              ('original_glcm_Autocorrelation', array(235.98522687)),
#              ('original_glcm_ClusterProminence', array(50.90743071)),
#              ('original_glcm_ClusterShade', array(-2.98874427)),
#              ('original_glcm_ClusterTendency', array(3.66842769)),
#              ('original_glcm_Contrast', array(0.98617113)),
#              ('original_glcm_Correlation', array(0.57609209)),
#              ('original_glcm_DifferenceAverage', array(0.70789175)),
#              ('original_glcm_DifferenceEntropy', array(1.44077426)),
#              ('original_glcm_DifferenceVariance', array(0.47866921)),
#              ('original_glcm_Id', array(0.68884924)),
#              ('original_glcm_Idm', array(0.67367815)),
#              ('original_glcm_Idmn', array(0.99755477)),
#              ('original_glcm_Idn', array(0.96688446)),
#              ('original_glcm_Imc1', array(-0.1422461)),
#              ('original_glcm_Imc2', array(0.66413475)),
#              ('original_glcm_InverseVariance', array(0.49683286)),
#              ('original_glcm_JointAverage', array(15.33996937)),
#              ('original_glcm_JointEnergy', array(0.08852618)),
#              ('original_glcm_JointEntropy', array(3.98147288)),
#              ('original_glcm_MCC', array(0.64438022)),
#              ('original_glcm_MaximumProbability', array(0.15790425)),
#              ('original_glcm_SumAverage', array(30.67993873)),
#              ('original_glcm_SumEntropy', array(2.9586274)),
#              ('original_glcm_SumSquares', array(1.1636497)),
#              ('original_gldm_DependenceEntropy', array(4.89425567)),
#              ('original_gldm_DependenceNonUniformity', array(154241.03371347)),
#              ('original_gldm_DependenceNonUniformityNormalized',
#               array(0.15658877)),
#              ('original_gldm_DependenceVariance', array(3.05395337)),
#              ('original_gldm_GrayLevelNonUniformity', array(261485.87774605)),
#              ('original_gldm_GrayLevelVariance', array(1.17740329)),
#              ('original_gldm_HighGrayLevelEmphasis', array(236.49601272)),
#              ('original_gldm_LargeDependenceEmphasis', array(21.36313448)),
#              ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#               array(5050.52508662)),
#              ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#               array(0.09178223)),
#              ('original_gldm_LowGrayLevelEmphasis', array(0.0043209)),
#              ('original_gldm_SmallDependenceEmphasis', array(0.12621606)),
#              ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#               array(29.88065815)),
#              ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#               array(0.00055677)),
#              ('original_glrlm_GrayLevelNonUniformity', array(142348.07296762)),
#              ('original_glrlm_GrayLevelNonUniformityNormalized',
#               array(0.24492929)),
#              ('original_glrlm_GrayLevelVariance', array(1.35307706)),
#              ('original_glrlm_HighGrayLevelRunEmphasis', array(236.55140467)),
#              ('original_glrlm_LongRunEmphasis', array(4.24839002)),
#              ('original_glrlm_LongRunHighGrayLevelEmphasis',
#               array(1004.67672418)),
#              ('original_glrlm_LongRunLowGrayLevelEmphasis', array(0.01828417)),
#              ('original_glrlm_LowGrayLevelRunEmphasis', array(0.00433597)),
#              ('original_glrlm_RunEntropy', array(3.88046098)),
#              ('original_glrlm_RunLengthNonUniformity', array(251455.93089531)),
#              ('original_glrlm_RunLengthNonUniformityNormalized',
#               array(0.4295013)),
#              ('original_glrlm_RunPercentage', array(0.59013464)),
#              ('original_glrlm_RunVariance', array(1.3357327)),
#              ('original_glrlm_ShortRunEmphasis', array(0.67368567)),
#              ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#               array(159.39959202)),
#              ('original_glrlm_ShortRunLowGrayLevelEmphasis', array(0.00293099)),
#              ('original_glszm_GrayLevelNonUniformity', array(22645.34879736)),
#              ('original_glszm_GrayLevelNonUniformityNormalized',
#               array(0.186535)),
#              ('original_glszm_GrayLevelVariance', array(2.50211272)),
#              ('original_glszm_HighGrayLevelZoneEmphasis', array(237.15832784)),
#              ('original_glszm_LargeAreaEmphasis', array(2754.91526359)),
#              ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#               array(657434.82166392)),
#              ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#               array(11.61583766)),
#              ('original_glszm_LowGrayLevelZoneEmphasis', array(0.00443695)),
#              ('original_glszm_SizeZoneNonUniformity', array(27397.45209226)),
#              ('original_glszm_SizeZoneNonUniformityNormalized',
#               array(0.22567918)),
#              ('original_glszm_SmallAreaEmphasis', array(0.47849931)),
#              ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#               array(113.41033496)),
#              ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#               array(0.00215905)),
#              ('original_glszm_ZoneEntropy', array(5.72177214)),
#              ('original_glszm_ZonePercentage', array(0.12324786)),
#              ('original_glszm_ZoneVariance', array(2689.08262529)),
#              ('original_ngtdm_Busyness', array(239.69129583)),
#              ('original_ngtdm_Coarseness', array(8.21824761e-06)),
#              ('original_ngtdm_Complexity', array(129.52921576)),
#              ('original_ngtdm_Contrast', array(0.00332617)),
#              ('original_ngtdm_Strength', array(0.00437705))])

# %% [markdown]
# key operations and parameters being applied:
#
# Parameter File Loading:
#
# The YAML file params-arterial.yaml is successfully loaded, specifying parameters like bin width, resampling spacing, and features to extract.
# Image and ROI (Region of Interest):
#
# The mask is cast to UInt32 to ensure the correct data type.
# Resampling is applied to match specified pixel spacing [1.075, 1.075, 1.25].
# The bounding box for the ROI is computed, and its validity is confirmed.
# Feature Classes:
#
# Enabled feature classes: firstorder, shape, glcm, gldm, glrlm, glszm, and ngtdm.
# Shape features like volume and surface area are calculated using the cropped mask.
# First-order features are calculated with gray levels discretized into 56 bins (based on a bin width of 25).
# Texture features such as GLCM, GLDM, and GLRLM matrices are computed, processed, and feature coefficients are derived.
# Warnings and Validations:
#
# A warning highlights that Sum Average in GLCM is symmetrical, reducing redundant calculations.
# Checks confirm that the mask includes the correct label and meets minimum

# %% [markdown]
# ## Conclusion
#
# Here, we have learned how to programatically organize and preprocess data for visualization and radiomic feature extraction.
#
# If you do not feel comfortable with using Python - that is perfectly fine! Computer software programs such as [3D Slicer](https://www.slicer.org/) feature [radiomic feature extraction](https://www.radiomics.io/slicerradiomics.html) plugins. This can also be automated as necessary, rendering these approaches widely applicable.

# %% [markdown]
# # Model training and tuning

# %% [markdown]
# Loading the data
# We will use here the complete set of features from WAW-TACE as extracted in the previous section. We start by selecting the largest lesion and by filling in the lesion sizes for the 2nd and 3rd largest lesions (if available). For the rest of the data we will be using disease progression as our target.

# %%
import pandas as pd
import numpy as np

# %%
# relevant paths and constants are defined here
clinical_data_target_path = "/content/drive/My Drive/Colab Notebooks/RadSignature/clinical_data_wawtace_v2_15_07_2024.xlsx"
arterial_feature_df_path = "../data/all_data_1.csv"
portal_feature_df_path = "../data/all_data_2.csv"
size_feature = "original_shape_VoxelVolume"

df_target = pd.read_excel(clinical_data_target_path)
dfs = {
    "Arterial": pd.read_csv(arterial_feature_df_path),
    "Portal": pd.read_csv(portal_feature_df_path),
}

new_df = {
    "Arterial": [],
    "Portal": []
}
for k in dfs:
    df = dfs[k]
    n = 0
    for patient in df["identifier"].unique():
        sub_df = df[df["identifier"] == patient].copy()
        if sub_df.shape[0] > 1:
            keep_lesion = sub_df.sort_values(size_feature).iloc[-1] # keep only last (largest)
            lesion_sizes = sorted(sub_df[size_feature])[:-1][::-1] # exclude last (largest)
            if len(lesion_sizes) == 1:
                lesion_sizes = [lesion_sizes[0], 0]
            keep_lesion["2nd_largest_size"] = lesion_sizes[0]
            keep_lesion["3nd_largest_size"] = lesion_sizes[1]
            sub_df = pd.DataFrame(keep_lesion).T
        else:
            sub_df.loc[:, "2nd_largest_size"] = 0
            sub_df.loc[:, "3nd_largest_size"] = 0
        cols_to_drop = ["phase", "mask_idx"]
        cols_to_drop.extend([x for x in sub_df.columns if "diagnostics" in x])
        sub_df.drop(cols_to_drop, inplace=True, axis=1)
        sub_df.columns = [f"{x}_{k}" if x != "identifier" else x for x in sub_df.columns]
        new_df[k].append(sub_df)
        n += 1

new_df["Arterial"] = pd.concat(new_df["Arterial"], axis=0)
new_df["Portal"] = pd.concat(new_df["Portal"], axis=0)

radiomics_df = pd.merge(new_df["Arterial"], new_df["Portal"])

# %%
radiomics_df
# Out:
#     original_shape_Elongation_Arterial original_shape_Flatness_Arterial  \
# 0                             0.837296                         0.694129
# 1                             0.838737                         0.818634
# 2                             0.989452                         0.672488
# 3                             0.662138                         0.629182
# 4                             0.786807                         0.651394
# ..                                 ...                              ...
# 221                             0.8959                         0.599339
# 222                           0.605449                         0.457891
# 223                           0.897425                         0.816176
# 224                           0.865186                         0.688782
# 225                           0.912578                         0.846985
#
#     original_shape_LeastAxisLength_Arterial  \
# 0                                 54.195568
# 1                                 46.809573
# 2                                 29.298201
# 3                                 49.464296
# 4                                 35.319262
# ..                                      ...
# 221                               57.389109
# 222                               33.286311
# 223                               37.688055
# 224                               89.002259
# 225                               24.131797
#
#     original_shape_MajorAxisLength_Arterial  \
# 0                                 78.077131
# 1                                 57.180091
# 2                                 43.566847
# 3                                 78.616849
# 4                                 54.221025
# ..                                      ...
# 221                               95.754003
# 222                                72.69476
# 223                               46.176401
# 224                              129.216813
# 225                               28.491425
#
#     original_shape_Maximum2DDiameterColumn_Arterial  \
# 0                                         79.879112
# 1                                          73.55636
# 2                                         48.798465
# 3                                         71.669139
# 4                                         69.614301
# ..                                              ...
# 221                                       101.42708
# 222                                       62.173729
# 223                                       52.875704
# 224                                        143.5778
# 225                                       32.655934
#
#     original_shape_Maximum2DDiameterRow_Arterial  \
# 0                                      93.033597
# 1                                      73.051887
# 2                                      51.302072
# 3                                      91.478372
# 4                                      51.345162
# ..                                           ...
# 221                                   105.897608
# 222                                    81.221184
# 223                                    50.927455
# 224                                    137.65397
# 225                                    33.095327
#
#     original_shape_Maximum2DDiameterSlice_Arterial  \
# 0                                        77.698041
# 1                                        57.740613
# 2                                        49.799312
# 3                                         79.06185
# 4                                         60.09433
# ..                                             ...
# 221                                     105.069913
# 222                                      55.087853
# 223                                      49.741264
# 224                                     132.691763
# 225                                      30.595038
#
#     original_shape_Maximum3DDiameter_Arterial  \
# 0                                    93.45719
# 1                                   73.799475
# 2                                   53.420807
# 3                                   92.949463
# 4                                   69.821498
# ..                                        ...
# 221                                108.759343
# 222                                 81.285185
# 223                                 56.419911
# 224                                153.037291
# 225                                 34.076532
#
#     original_shape_MeshVolume_Arterial  \
# 0                        193403.671682
# 1                         89791.889899
# 2                         39108.183209
# 3                        131284.801981
# 4                         57874.668155
# ..                                 ...
# 221                       328140.77107
# 222                       69012.968102
# 223                       51643.260734
# 224                      910509.067087
# 225                       12776.398529
#
#     original_shape_MinorAxisLength_Arterial  ...  \
# 0                                 65.373647  ...
# 1                                 47.959079  ...
# 2                                 43.107303  ...
# 3                                 52.055228  ...
# 4                                 42.661484  ...
# ..                                      ...  ...
# 221                                  85.786  ...
# 222                                44.01298  ...
# 223                               41.439871  ...
# 224                              111.796579  ...
# 225                               26.000659  ...
#
#     original_glszm_ZoneEntropy_Portal original_glszm_ZonePercentage_Portal  \
# 0                            5.616258                             0.180583
# 1                            5.487772                             0.254461
# 2                            5.050587                              0.15402
# 3                            5.432544                             0.182925
# 4                            5.463129                             0.061421
# ..                                ...                                  ...
# 221                          5.196633                              0.09897
# 222                           5.21707                             0.237457
# 223                          5.271053                             0.112288
# 224                          5.921886                              0.10892
# 225                          5.198599                             0.080397
#
#     original_glszm_ZoneVariance_Portal original_ngtdm_Busyness_Portal  \
# 0                           415.923808                      93.260333
# 1                            96.732914                      13.912539
# 2                           868.864104                      44.492427
# 3                           586.995045                     138.452291
# 4                         10244.377787                       5.266737
# ..                                 ...                            ...
# 221                        6636.242042                       7.909368
# 222                         138.610414                      66.090673
# 223                        1526.059444                      59.459043
# 224                        3598.811068                     202.577692
# 225                         1546.23686                      15.650082
#
#     original_ngtdm_Coarseness_Portal original_ngtdm_Complexity_Portal  \
# 0                           0.000093                        51.645535
# 1                           0.000288                        97.450501
# 2                           0.000329                        21.748154
# 3                           0.000036                        62.640074
# 4                            0.00066                       602.055487
# ..                               ...                              ...
# 221                         0.000047                       673.021055
# 222                         0.000219                        34.279283
# 223                          0.00035                        14.078798
# 224                         0.000007                       144.305239
# 225                         0.001442                        12.056536
#
#     original_ngtdm_Contrast_Portal original_ngtdm_Strength_Portal  \
# 0                         0.012845                       0.007815
# 1                         0.015114                       0.045057
# 2                         0.014251                       0.011753
# 3                         0.007465                        0.00459
# 4                         0.003179                      13.980325
# ..                             ...                            ...
# 221                       0.000977                        0.43372
# 222                       0.021247                       0.008447
# 223                       0.013597                       0.009198
# 224                        0.00254                       0.005118
# 225                       0.009235                       0.044225
#
#     2nd_largest_size_Portal 3nd_largest_size_Portal
# 0                         0                       0
# 1                         0                       0
# 2              11959.075928             5710.601807
# 3                         0                       0
# 4                         0                       0
# ..                      ...                     ...
# 221                       0                       0
# 222             5488.395691                       0
# 223                       0                       0
# 224                       0                       0
# 225                       0                       0
#
# [226 rows x 219 columns]

# %%
target_var = "progression"

relevant_columns = [
    "age", # patient age
    "gender_woman", # whether patient identifies as woman
    "etiology_mixed", # whether tumor etiology is mixed
    "etiology_HCV", # whether tumor etiology is hep C
    "etiology_HBV", # whether tumor etiology is hep B
    "etiology_alcoholic", # whether tumor etiology is alcoholic
    "etiology_NASH", # whether tumor etiology is nonalcoholic steatohepatitis
    "etiology_cryptogenic", # whether etiology is unknown
    "lab_albumin", # albumin concentration
    "lab_creatinine", # creatinine concentration
    "lab_bilirubin", # bilirubin concentration
    "lab_afp", # alfa-fetoprotein concentration
    "lab_inr", # prothrombin international normalised ratio
    "lab_alt", # alanine aminotransferase
    "lesion1_diameter", # largest lesion diameter
    "lesion2_diameter", # 2nd largest lesion diameter
    "lesion3_diameter", # 3rd largest lesion diameter
    "lesion1_LIRADS", # largest lesion LI-RADS
    "lesion2_LIRADS", # 2nd largest lesion LI-RADS
    "lesion3_LIRADS", # 3nd largest lesion LI-RADS
    # combined positive score (PD-L1 positive cells / viable tumour cells)
    "cps",
    # Barcelona clinic liver cancer score (number and size of tumours, general health and fitness, liver function)
    "bclc",
    # HAP score (albumin, bilirubin, AFP, tumour size)
    "hap_score",
    # modified hepatoma arterial embolisation prognostic II (HAP + tumour number)
    "mhap_2",
    # albumin and bilirubin, tumour size * number of tumours
    "albi_tae",
    # 6 and 12 score (tumour size, number of tumours)
    "6_12_score",
]

df_target_processed = df_target[["PATPRI", *relevant_columns, target_var]].copy()
df_target_processed["identifier"] = df_target_processed["PATPRI"]
df_target_processed["class"] = df_target_processed[target_var]
df_target_processed = df_target_processed.drop(["PATPRI", target_var],axis=1)
df_class = df_target_processed.loc[:, ["identifier", "class"]]
df_clinical = df_target_processed.drop(["class"],axis=1)
for k in ["lesion2_diameter", "lesion3_diameter", "lesion2_LIRADS", "lesion3_LIRADS"]:
    if k in df_clinical:
        df_clinical[k] = df_clinical[k].fillna(0)

for k in ["lesion1_LIRADS"]:
    if k in df_clinical:
        df_clinical[k] = np.where(df_clinical[k] == "M", 6, df_clinical[k])

df_clinical = df_clinical.dropna(axis=0)

# %%
generate_test_set = False

if generate_test_set is True:
    test_set_size = 0.25
    from sklearn.model_selection import train_test_split

    with open("test_patients", "w") as o:
        ids = df_class["identifier"].astype(str).tolist()
        classes = df_class["class"].tolist()
        train_split, test_split = train_test_split(
            ids,
            test_size=test_set_size,
            random_state=42,
            stratify=classes)
        print(len(train_split), len(test_split))
        o.write("\n".join(test_split))

# %% [markdown]
# Make data splits
# Here, we are setting aside 25% of the data for a hold-out test set. We will not touch the hold-out test data except for the actual testing at the end!

# %%
with open("test_patients") as o:
    test_patients = [x.strip() for x in o.readlines()]

full_df = pd.merge(
    pd.merge(radiomics_df, df_class),
    df_clinical)

train_full_df = full_df[~np.in1d(full_df.identifier.astype(str), test_patients)]

train_radiomics_df = train_full_df.drop(relevant_columns, axis=1)
train_clinical_df = train_full_df[["identifier", *relevant_columns, "class"]]

# %% [markdown]
# Now is also a good time to assess how the target is distributed between negative and positive cases (no progression and progression, respectively).

# %%
train_clinical_df["class"].value_counts()
# Out:
# class
# 0    129
# 1     41
# Name: count, dtype: int64

# %% [markdown]
# Here he data is somewhat unbalanced (1 progressor for every 3 non-progressors). This can make the application of metrics which do not consider this (i.e. accuracy) a bit tricky!

# %% [markdown]
# Inspecting the data - minimal exploratory data analysis
# Let us now take the time to plot the data and some of the features and see how they are distributed. Here, we will pick the features showing the highest association with our target variable according to a t-test.

# %%
from scipy import stats # library to perform statistics in Python

ttest_results = {}
target = train_radiomics_df["class"]
for x in train_radiomics_df:
    if x not in ["identifier", "phase", "mask_idx", "class"]:
        feature = train_radiomics_df[x]
        ttest_result = stats.ttest_ind(
            feature[target == 0].astype(float),
            feature[target == 1].astype(float))
        if ttest_result.pvalue < 0.05:
            ttest_results[x] = ttest_result.statistic

ttest_results_clinical = {}
target = train_clinical_df["class"]
for x in train_clinical_df:
    if x not in ["identifier", "class"] and "etiology" not in x:
        feature = train_clinical_df[x]
        ttest_result = stats.ttest_ind(
            feature[target == 0].astype(float),
            feature[target == 1].astype(float))
        if ttest_result.pvalue < 0.05:
            ttest_results_clinical[x] = ttest_result.statistic
# Out:
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import seaborn as sbn # plotting library
import matplotlib.pyplot as plt

top_n = 5

ttest_results_sorted = sorted(ttest_results.keys(), key=lambda k: -ttest_results[k] ** 2)

for key in ttest_results_sorted[:top_n]:
    sbn.boxplot(x="class", y=key, data=train_radiomics_df)
    plt.show()

# %% [markdown]
# We now do the same for the clinical features. Clearly we see there are more radiomics features which are associated with the target variable - this could be a good indication!

# %%
ttest_results_sorted = sorted(ttest_results_clinical.keys(), key=lambda k: -ttest_results_clinical[k] ** 2)

for key in ttest_results_sorted[:top_n]:
    sbn.boxplot(x="class", y=key, data=train_clinical_df)
    plt.show()

# %% [markdown]
# Building our model
# Here we will define a pipeline (Pipeline) containing a set of components which we have previously discussed are aluded to:
#
# VarianceThreshold will (mostly) remove constant features
# StandardScaler will scale the data such that each feature has (Mue=0)
#  and (Segma=1)
# RandomForestClassifier will be our random forest classifier
# We will first assess the expected performance of our method for hyperparameter selection using nested cross-validation. We will be performing this for three distinct feature sets:
#
# 1. Radiomics
# 2. Clinical (all of the clinical features)
# 3. Radclin (radiomics and clinical features)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, cross_validate
from scipy.stats import randint

df_dict = {
    "radiomics": train_radiomics_df,
    "clinical": train_clinical_df,
    "full": train_full_df,
}
results = {}
inner_folds = 5
outer_folds = 5

for key in df_dict:
    np.random.seed(42)
    params = {
        "model__n_estimators": randint(5, 100),
        "model__max_depth": randint(5, 20)
    }
    pipeline = Pipeline(
        [("variance_threshold", VarianceThreshold()),
         ("scaler", StandardScaler()),
         ("model", RandomForestClassifier(
             class_weight="balanced",
             random_state=42))]
    )
    curr_df = df_dict[key]
    print(f"Training with {key} data (shape={curr_df.shape})")
    X = curr_df.drop("class", axis=1).astype(np.float32).to_numpy()
    y = curr_df["class"].to_numpy()

    inner_cv = StratifiedKFold(
        n_splits=inner_folds, shuffle=True, random_state=42)
    outer_cv = StratifiedKFold(
        n_splits=outer_folds, shuffle=True, random_state=42)

    inner_model = RandomizedSearchCV(
        pipeline, params, cv=inner_cv, n_iter=100, scoring="roc_auc",
        random_state=42)
    nested_score = cross_validate(
        inner_model,
        X=X,
        y=y,
        cv=outer_cv,
        scoring="roc_auc",
        verbose=2,
        return_estimator=True,
        n_jobs=min([outer_folds, 7]),
        )

    results[key] = nested_score

    print(key, np.mean(results[key]["test_score"]))
# Out:
# Training with radiomics data (shape=(170, 220))
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  5.3min remaining:  7.9min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  5.3min finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# radiomics 0.7080619658119659
# Training with clinical data (shape=(170, 28))
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  4.2min remaining:  6.2min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  4.2min finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# clinical 0.5398547008547008
# Training with full data (shape=(170, 246))
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  5.0min remaining:  7.5min
# full 0.6505405982905983
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  5.0min finished

# %%
results_df = pd.DataFrame(
    {"AUC": np.concatenate([
        results['radiomics']['test_score'],
        results['clinical']['test_score'],
        results['full']['test_score']
        ]),
     "Features": np.concatenate(
        [["Radiomics" for _ in range(outer_folds)],
         ["Clinical" for _ in range(outer_folds)],
         ["Radclin" for _ in range(outer_folds)]])}
     )

sbn.pointplot(x="AUC", y="Features", data=results_df, linestyle='')
# Out:
# <Axes: xlabel='AUC', ylabel='Features'>

# %%
from scipy import stats

print("Radiomics vs. clinical:", stats.ttest_ind(results["radiomics"]["test_score"], results["clinical"]["test_score"]))
print("Radiomics+clinical vs. clinical:", stats.ttest_ind(results["full"]["test_score"], results["clinical"]["test_score"]))
print("Radiomics vs. radiomics+clinical:", stats.ttest_ind(results["radiomics"]["test_score"], results["full"]["test_score"]))
# Out:
# Radiomics vs. clinical: TtestResult(statistic=2.7748709804334757, pvalue=0.024114684284166618, df=8.0)
# Radiomics+clinical vs. clinical: TtestResult(statistic=2.4316442397877522, pvalue=0.041096694330042004, df=8.0)
# Radiomics vs. radiomics+clinical: TtestResult(statistic=1.244359043496507, pvalue=0.2485871093164487, df=8.0)

# %%
import joblib # here we are using this library to save our model
import os

os.makedirs("model", exist_ok=True)
joblib.dump(results, "model/all_models.joblib")
# Out:
# ['model/all_models.joblib']

# %% [markdown]
# Excellent! We appear to have an improvement on progression prediction both using radiomic features and using all features (clinical and radiomics).
#
# We are only missing one last part of our approach: validating our models on our hold-out test set.

# %% [markdown]
# ### Validation

# %%
test_full_df = full_df[np.in1d(full_df.identifier.astype(str), test_patients)]

test_radiomics_df = test_full_df.drop(relevant_columns, axis=1)
test_clinical_df = test_full_df[["identifier", *relevant_columns, "class"]]

# %%
from sklearn.metrics import roc_auc_score

test_df_dict = {
    "radiomics": test_radiomics_df,
    "clinical": test_clinical_df,
    "full": test_full_df,
}

for key in test_df_dict:
    curr_df = test_df_dict[key]
    X = curr_df.drop("class", axis=1).astype(np.float32).to_numpy()
    y = curr_df["class"].to_numpy()

    probas = [estimator.predict_proba(X)[:, 1]
              for estimator in results[key]["estimator"]]
    probas = np.array(probas).mean(0)

    predictions = [estimator.predict(X)
                   for estimator in results[key]["estimator"]]
    predictions = np.array(predictions).mean(0) > 0.5

    print(
        f"{key}: ROC={roc_auc_score(y, probas)}"
    )
# Out:
# radiomics: ROC=0.6846689895470384
# clinical: ROC=0.5209059233449478
# full: ROC=0.6829268292682926

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
# Iterate through the test dictionaries and plot ROC curves
plt.figure(figsize=(8, 6))

for key in test_df_dict:
    curr_df = test_df_dict[key]
    X = curr_df.drop("class", axis=1).astype(np.float32).to_numpy()
    y = curr_df["class"].to_numpy()

    # Calculate probabilities and predictions
    probas = [estimator.predict_proba(X)[:, 1] for estimator in results[key]["estimator"]]
    probas = np.array(probas).mean(0)

    # Compute the ROC curve and AUC
    fpr, tpr, _ = roc_curve(y, probas)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    plt.plot(fpr, tpr, label=f"{key} (AUC = {roc_auc:.2f})")

# Plot aesthetics
plt.plot([0, 1], [0, 1], "k--", label="Random Guess (AUC = 0.50)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Interpreting the ROC curve figure involves assessing the model's performance in distinguishing between the positive and negative classes.

# %% [markdown]
# Curve Shape:
#
# A curve closer to the top-left corner indicates better performance. This suggests a high True Positive Rate (TPR) and a low False Positive Rate (FPR).
# A curve along the diagonal line (from bottom-left to top-right) indicates random guessing, with no discrimination between classes (AUC = 0.5).
# Area Under the Curve (AUC):
#
# AUC = 1: Perfect classification.
# AUC > 0.8: Excellent performance.
# AUC between 0.7–0.8: Acceptable or moderate performance.
# AUC < 0.7: Poor performance, suggesting the model struggles to distinguish between classes.

# %% [markdown]
# at this example Radiomics: If the radiomics curve is closer to the top-left and has a higher AUC (e.g., 0.68), this suggests moderate discriminatory power for the radiomics-based model.
# Clinical: If the clinical model’s ROC curve is near the diagonal line and its AUC is close to 0.51, it performs only slightly better than random guessing.
# Full: If the "full" model (combining radiomics and clinical features) has an AUC close to the radiomics model, it suggests that the addition of clinical features does not significantly improve the model.

# %% [markdown]
# ### Plot Sensitivity vs Specifisity

# %% [markdown]
# What does it mean? ☕
# Sensitivity (True Positive Rate): The proportion of actual positives correctly identified.
# Specificity: The proportion of actual negatives correctly identified.
# Specificity=1−False Positive Rate.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

# Example dictionary for ROC-AUC results
test_df_dict = {
    "radiomics": test_radiomics_df,
    "clinical": test_clinical_df,
    "full": test_full_df,
}

# Define colors for each model
model_colors = {
    "radiomics": "blue",
    "clinical": "green",
    "full": "red"
}
# Create the figure
plt.figure(figsize=(8, 6))

for key in test_df_dict:
    curr_df = test_df_dict[key]
    X = curr_df.drop("class", axis=1).astype(np.float32).to_numpy()
    y = curr_df["class"].to_numpy()

    # Predict probabilities
    probas = [estimator.predict_proba(X)[:, 1] for estimator in results[key]["estimator"]]
    probas = np.array(probas).mean(0)

    # Calculate sensitivity and 1-specificity
    fpr, tpr, thresholds = roc_curve(y, probas)
    specificity = 1 - fpr  # Convert FPR to specificity

    # Plot sensitivity vs. specificity
    plt.plot(specificity, tpr, label=f"{key} (AUC={roc_auc_score(y, probas):.3f})", color=model_colors[key])

# Add labels and legend
plt.xlabel("Specificity")
plt.ylabel("Sensitivity")
plt.title("Sensitivity vs. Specificity for Radiomics, Clinical, and Full Models")
plt.legend()
plt.grid(alpha=0.3)
plt.gca().invert_xaxis()  # Invert the x-axis for specificity
plt.tight_layout()
# Show the plot
plt.show()
